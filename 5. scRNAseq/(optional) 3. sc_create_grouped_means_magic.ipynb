# %%
import scanpy as sc
import pandas as pd
import os
import numpy as np

# %%
# error settings to avoid crowding the notebook
sc.settings.verbosity = 0             # verbosity: errors (0), warnings (1), info (2), hints (3)

# %% [markdown]
# Load definitions

# %%
def grouped_obs_mean(adata, group_key, layer=None, gene_symbols=None):
    if layer is not None:
        getX = lambda x: x.layers[layer]
    else:
        getX = lambda x: x.X
    if gene_symbols is not None:
        new_idx = adata.var[idx]
    else:
        new_idx = adata.var_names

    grouped = adata.obs.groupby(group_key)
    out = pd.DataFrame(
        np.zeros((adata.shape[1], len(grouped)), dtype=np.float64),
        columns=grouped.groups.keys(),
        index=adata.var_names
    )

    for group, idx in grouped.indices.items():
        X = getX(adata[idx])
        out[group] = np.ravel(X.mean(axis=0, dtype=np.float64))
    return out

def marker_gene_expression(anndata, marker_dict, gene_symbol_key=None, partition_key='louvain_r1'):
    """
    A function to get mean z-score expressions of marker genes
    # 
    # Inputs:
    #    anndata         - An AnnData object containing the data set and a partition
    #    marker_dict     - A dictionary with cell-type markers. The markers should be stores as anndata.var_names or 
    #                      an anndata.var field with the key given by the gene_symbol_key input
    #    gene_symbol_key - The key for the anndata.var field with gene IDs or names that correspond to the marker 
    #                      genes
    #    partition_key   - The key for the anndata.obs field where the cluster IDs are stored. The default is
    #                      'louvain_r1' 
    """

    #Test inputs
    if partition_key not in anndata.obs.columns.values:
        print('KeyError: The partition key was not found in the passed AnnData object.')
        print('   Have you done the clustering? If so, please tell pass the cluster IDs with the AnnData object!')
        raise

    if (gene_symbol_key != None) and (gene_symbol_key not in anndata.var.columns.values):
        print('KeyError: The provided gene symbol key was not found in the passed AnnData object.')
        print('   Check that your cell type markers are given in a format that your anndata object knows!')
        raise
        
    if gene_symbol_key:
        gene_ids = anndata.var[gene_symbol_key]
    else:
        gene_ids = anndata.var_names

    clusters = anndata.obs[partition_key].cat.categories
    n_clust = len(clusters)
    marker_exp = pd.DataFrame(columns=clusters)
    marker_exp['cell_type'] = pd.Series({}, dtype='str')
    marker_names = []
    
    z_scores = sc.pp.scale(anndata, copy=True)

    i = 0
    for group in marker_dict:
        # Find the corresponding columns and get their mean expression in the cluster
        for gene in marker_dict[group]:
            ens_idx = np.in1d(gene_ids, gene) #Note there may be multiple mappings
            if np.sum(ens_idx) == 0:
                continue
            else:
                z_scores.obs[ens_idx[0]] = z_scores.X[:,ens_idx].mean(1) #works for both single and multiple mapping
                ens_idx = ens_idx[0]

            clust_marker_exp = z_scores.obs.groupby(partition_key)[ens_idx].apply(np.mean).tolist()
            clust_marker_exp.append(group)
            marker_exp.loc[i] = clust_marker_exp
            marker_names.append(gene)
            i+=1

    #Replace the rownames with informative gene symbols
    marker_exp.index = marker_names

    return(marker_exp)

# %% [markdown]
# ### Read  scRNA-seq data

# %%
#anndata_all = sc.read_h5ad('mli_raw_annotated.h5ad')
anndata_all = sc.read_h5ad('/home/sanjavickovic/data/magic_genes/magic_subset_sig_all_genes.h5ad')
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-4-edc468c34499> in <module>()
#       1 #anndata_all = sc.read_h5ad('mli_raw_annotated.h5ad')
# ----> 2 anndata_all = sc.read_h5ad('/home/sanjavickovic/data/magic_genes/magic_subset_sig_all_genes.h5ad')
#
# /home/sanjavickovic/miniconda3/envs/stenv3/lib/python3.7/site-packages/anndata/_io/h5ad.py in read_h5ad(filename, backed, as_sparse, as_sparse_fmt, chunk_size)
#     411     )
#     412
# --> 413     with h5py.File(filename, "r") as f:
#     414         d = {}
#     415         for k in f.keys():
#
# /home/sanjavickovic/miniconda3/envs/stenv3/lib/python3.7/site-packages/h5py/_hl/files.py in __init__(self, name, mode, driver, libver, userblock_size, swmr, rdcc_nslots, rdcc_nbytes, rdcc_w0, track_order, **kwds)
#     406                 fid = make_fid(name, mode, userblock_size,
#     407                                fapl, fcpl=make_fcpl(track_order=track_order),
# --> 408                                swmr=swmr)
#     409
#     410             if isinstance(libver, tuple):
#
# /home/sanjavickovic/miniconda3/envs/stenv3/lib/python3.7/site-packages/h5py/_hl/files.py in make_fid(name, mode, userblock_size, fapl, fcpl, swmr)
#     171         if swmr and swmr_support:
#     172             flags |= h5f.ACC_SWMR_READ
# --> 173         fid = h5f.open(name, flags, fapl=fapl)
#     174     elif mode == 'r+':
#     175         fid = h5f.open(name, h5f.ACC_RDWR, fapl=fapl)
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py/h5f.pyx in h5py.h5f.open()
#
# OSError: Unable to open file (unable to open file: name = '/home/sanjavickovic/data/magic_genes/magic_subset_sig_all_genes.h5ad', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)

# %%
anndata_all.var_names
# Out:
# Index(['Mrpl15', 'Lypla1', 'Tcea1', 'Atp6v1h', 'Rb1cc1', 'Vcpip1', 'Snhg6',
#        'Cops5', 'Cspp1', 'Arfgef1',
#        ...
#        'Hccs', 'mt-Nd1', 'mt-Nd2', 'mt-Co1', 'mt-Nd4', 'mt-Nd5', 'mt-Nd6',
#        'mt-Cytb', 'Vamp7', 'Tmlhe'],
#       dtype='object', length=6825)

# %%
anndata_all.var_names_make_unique()

# %%
# copy of object
adata = anndata_all

# %% [markdown]
# ## Make grouped means

# %%
adata_zscore_norm = grouped_obs_mean(adata, 'pheno_cell_types')

# %%
adata_zscore_norm.to_csv('/home/sanjavickovic/data/sc_mli_scores/mli_zscore_norm_all_pheno_log_magic.csv')

# %%
sc.pp.scale(adata, max_value=10)

# %%
adata_zscore_norm_scaled = grouped_obs_mean(adata, 'pheno_cell_types')

# %%
adata_zscore_norm_scaled.to_csv('/home/sanjavickovic/data/sc_mli_scores/mli_zscore_norm_scaled_all_pheno_log_magic.csv')

# %%
adata_zscore_norm_scaled_age = grouped_obs_mean(adata, ['pheno_cell_types', 'age',])

# %%
adata_zscore_norm_scaled_age.to_csv('/home/sanjavickovic/data/sc_mli_scores/mli_zscore_norm_scaled_all_pheno_age_log_magic.csv')

# %%
rank_genes_groups_keys = ['logfoldchanges', 'pvals_adj', 'scores']
rank_genes_groups = adata.uns['pheno_minor_cell_types']
group_names = rank_genes_groups['names'].dtype.names

group_df_final = list()
for group_name in group_names:
    gene_names = rank_genes_groups['names'][group_name]
    group_df = pd.DataFrame(index=gene_names)
    for rank_genes_groups_key in rank_genes_groups_keys:
        values = rank_genes_groups[rank_genes_groups_key][group_name]
        group_df[rank_genes_groups_key] = values
    group_df['cell_type'] = group_name
    group_df_final.append(group_df)

# %%
group_df_final = pd.concat(group_df_final)

# %%
group_df_final = group_df_final[(group_df_final['logfoldchanges'] > 2) & (group_df_final['pvals_adj'] < 0.01)]

# %%
markers_dict = dict()
for i in np.unique(group_df_final['cell_type']):
    markers_dict[i] = list(group_df_final[group_df_final['cell_type'] == i].index)

# %%
markers_dict
# Out:
# {'B_cell': ['S100a6',
#   'Gsdmc4',
#   'Actg1',
#   'Ftl1',
#   'Ckmt1',
#   'Slc25a5',
#   'Zcchc12',
#   'Kif2c',
#   'Zdhhc14',
#   'Cyp2c69',
#   'Ngfr',
#   'Abca13',
#   'Cplx2',
#   'Agt',
#   'Ly6g6d',
#   'Bcam',
#   'Krt23',
#   'Man1c1',
#   'Ms4a4d',
#   'Pygl',
#   'Aoc3',
#   'Camk2a',
#   'Crispld1',
#   '4930467D21Rik',
#   'A330102I10Rik',
#   'Ar',
#   'Vwf',
#   'Rasip1',
#   'Mettl21b',
#   '4930552P12Rik',
#   'Rep15',
#   'Ndrg4',
#   '2310079G19Rik',
#   'Gcg',
#   'Shc4',
#   'Sorcs2',
#   'Bmp6',
#   'Lrrc26',
#   'Gng4',
#   'Kif5a',
#   'Sv2a',
#   '5330434G04Rik',
#   'Resp18',
#   'Atp6v0a4',
#   'Fam212b',
#   'Aldh1a3',
#   'Spon2',
#   'Cnr1',
#   'Cdh5',
#   'Nuak1',
#   'Hap1',
#   'Wnt8b',
#   'Scn9a',
#   'Rarres2',
#   'Ms4a7',
#   'Add2',
#   'Mfap5',
#   'Adm',
#   'Vill',
#   'Chrdl1',
#   'Cadm3',
#   'Snap91',
#   'Htra3',
#   'Enpp2',
#   'Syt4',
#   'Kcnj3',
#   'Cdkn1c',
#   'Tnr',
#   'Gjb5',
#   'C130071C03Rik',
#   'Amn',
#   'Medag',
#   'Kcnq3',
#   'Upk1b',
#   'Gm12381',
#   'Iigp1',
#   'Muc16',
#   'Itga11',
#   'Tspan6',
#   'Trpm5',
#   'Dnah5',
#   'Elavl3',
#   'Slc7a14',
#   'Esam',
#   'Slc5a7',
#   'Gpm6a',
#   'Entpd3',
#   'Chrna3',
#   'Fam163a',
#   'Kcnh6',
#   '1700041M19Rik',
#   'Muc1',
#   'Ccdc85a',
#   'Atp2a3',
#   'Anxa13',
#   'Adam11',
#   'Pla2g7',
#   'Igsf10',
#   'Defb37',
#   'Gm12709',
#   'Tbxas1',
#   'Nags',
#   'Synpr',
#   'Lgi4',
#   'Spock1',
#   'Fbln5',
#   'Cemip',
#   'Mrc1',
#   'Unc13c',
#   'Slc29a4',
#   'Adgrg2',
#   '9430020K01Rik',
#   'Gria2',
#   'Alox5',
#   'Aebp1',
#   'Srpx2',
#   'Cyp2d9',
#   'Cyp3a44',
#   'Ralyl',
#   'Hs3st4',
#   'Mest',
#   'Tnfrsf11b',
#   'Atp2b2',
#   'Rit2',
#   'Avil',
#   'March4',
#   'Arg2',
#   'Alpi',
#   'Csf1',
#   'Nrxn2',
#   'Plat',
#   'Abca9',
#   'Evc2',
#   'Lrfn5',
#   'Myt1l',
#   'Musk',
#   'Armc2',
#   'Dlgap2',
#   'Tmprss5',
#   'Tbx2',
#   'Ccm2l',
#   'Jakmip2',
#   'Gfra3',
#   'Angptl4',
#   'Slc22a4',
#   'Kcnmb2',
#   'Gm16233',
#   'Speg',
#   'Slc6a17',
#   'Cd34',
#   'Sytl5',
#   'Lrrn2',
#   'Srrm4',
#   'Arhgef15',
#   'Cdh3',
#   'Clvs1',
#   'Cyp2j9',
#   'Fgf7',
#   'Vps13b',
#   'Grik4',
#   'Cyp3a25',
#   'Igsf21',
#   'Clip4',
#   'Rgs22',
#   'Nek10',
#   'Gm14342',
#   'Cspg4',
#   '1700057G04Rik',
#   'Gabbr2',
#   'Kcnk3',
#   'Cidec',
#   'Syt13',
#   'Acot4',
#   'Cldn5',
#   'Clstn2',
#   'Rgs13',
#   'Eya4',
#   'Kcna6',
#   'Ndst4',
#   'Gm1965',
#   'Cd300lg',
#   'Gm16183',
#   'Nalcn',
#   'Tie1',
#   'Cux2',
#   'Cfap44',
#   'Fam198b',
#   'Megf10',
#   'Fstl5',
#   'Igf2bp1',
#   'Elavl2',
#   '9530059O14Rik',
#   'Phactr3',
#   'Snhg11',
#   '1700111E14Rik',
#   'Dmtn',
#   'Ramp1',
#   'Acaa1b',
#   'Grid1',
#   'Nkx2-2os',
#   'Kcnc2',
#   'Shisa6',
#   'Kcnj6',
#   'Stab1',
#   'Vwa5b2',
#   'Lrch2',
#   'Arsj',
#   'Trpv6',
#   'Gm37459',
#   'Ildr2',
#   'RP24-274B19.1',
#   'Col6a4',
#   'Ppfia2',
#   'Slc8a3',
#   'Nfatc4',
#   'Nova1',
#   'Nxph1',
#   'Kcnh7',
#   'Ebf3',
#   'Pax6os1',
#   'Erg',
#   'A630023A22Rik',
#   'Ntf3',
#   'Wif1',
#   'Atp2c2',
#   'Soga3',
#   'Ggt1',
#   'Gm14964',
#   'Ptgis',
#   'Snca',
#   'Srcin1',
#   'Lbp',
#   'Prdm6',
#   'Olfr78',
#   'Rbm24',
#   'Pdk4',
#   'P2rx1',
#   'Thsd1',
#   'Kcnd2',
#   'Rsad2',
#   'Cacng4',
#   'Kcns3',
#   'Jam2',
#   'Gm20642',
#   'Agtr1a',
#   'Ces2b',
#   'Tacr1',
#   'Gdpd2',
#   'Flt1',
#   'Trpc4',
#   'Galnt15',
#   'Tnfaip8l3',
#   'Gabra3',
#   'Itga8',
#   'Ugt8a',
#   'Ddo',
#   'Jph1',
#   'Scube2',
#   'Cxxc4',
#   'Igf1',
#   '4930419G24Rik',
#   'Ntng1',
#   'Tph1',
#   'Gm17276',
#   'Ushbp1',
#   'Isl1',
#   'Chat',
#   'Tmem252',
#   'Col24a1',
#   'Bmx',
#   'Radil',
#   'Sh3gl3',
#   'Sh2d6',
#   'Ngf',
#   'Fam19a5',
#   'Scn2a1',
#   'Adgrg3',
#   'Galnt16',
#   'Cyp4x1',
#   'Clec1a',
#   'Gm14344',
#   'Gm15398',
#   'Abcc8',
#   'Myt1',
#   'Gpc3',
#   'Arhgap22',
#   'Gm15716',
#   'Dnm3os',
#   'Scn7a',
#   'Gabrb3',
#   'Faxc',
#   'Pdgfra',
#   'Bves',
#   '4833422C13Rik',
#   'Gm42439',
#   'Nrg3os',
#   '4930578C19Rik',
#   'Xkr4',
#   'Ednra',
#   'Agr2',
#   'Adamtsl3',
#   'Astn1',
#   'Fam184a',
#   'Vnn1',
#   'Kcnq4',
#   'Nfasc',
#   'Bdkrb2',
#   'Gm43507',
#   'Gm13052',
#   'Pappa',
#   'Ccdc129',
#   'Fgf10',
#   'Rfx6',
#   'Slc10a6',
#   'Ablim3',
#   'Efcc1',
#   'Syt14',
#   'Lmx1a',
#   'Arhgap28',
#   'Col4a6',
#   'Adgrl4',
#   'Stxbp5l',
#   'Adamts19',
#   'Tbx3os1',
#   'Hpse2',
#   'Col11a1',
#   'Slc38a11',
#   'Gm38505',
#   'Trpc3',
#   'Stk32a',
#   'Gm11149',
#   'Gm10848',
#   'Antxrl',
#   'Gm13269'],
#  'Colonocyte': ['Mgat5',
#   'Cemip',
#   'Cyp2c69',
#   'Arhgap33',
#   'Btk',
#   'Pyy',
#   'Nlrc5',
#   'Fabp4',
#   'Ano2',
#   'Kynu',
#   'Synpr',
#   'Ly6g6d',
#   'Hs3st4',
#   'Il16',
#   'Cux2',
#   'Plvap',
#   'B530045E10Rik',
#   'Adgre1',
#   'Chd5',
#   'Adgrg2',
#   'Raet1e',
#   'Cd247',
#   'Myl1',
#   'Ms4a1',
#   'Aldh1a3',
#   'Rgs22',
#   'F13a1',
#   'Pappa2',
#   'Tbx2',
#   'Csf1r',
#   'Sult4a1',
#   'Cd248',
#   'Megf10',
#   'Spib',
#   'Crispld1',
#   'Cdh8',
#   'Aoah',
#   'Gabra3',
#   'Krt23',
#   'Sh2d7',
#   'Il17rb',
#   'Cd93',
#   'Themis',
#   'Insm1',
#   'Pi16',
#   'Pkib',
#   'Tmem151a',
#   'Gabbr2',
#   'Zcchc12',
#   'C130071C03Rik',
#   'Rbm24',
#   'Tubb2b',
#   'Gbp5',
#   'Itga11',
#   'Plat',
#   'Igsf21',
#   'Gja5',
#   'Matk',
#   'Wif1',
#   'Scgn',
#   'Fcgr2b',
#   'C4b',
#   'Kcnj6',
#   'Nkain4',
#   'Ncf1',
#   'Ms4a4d',
#   'Fam212b',
#   'Eef1a2',
#   'Ahrr',
#   'Acap1',
#   'Ina',
#   'Selplg',
#   'Elmod1',
#   'Spon2',
#   'Pou2af1',
#   'Cyp2j9',
#   'Itgb7',
#   'Itgal',
#   'Musk',
#   'Tnfrsf11b',
#   'Igsf10',
#   'H2-DMb1',
#   'Vill',
#   'Htra3',
#   'Alox5',
#   'Atp6v0a4',
#   'Mfap5',
#   'Armc2',
#   'Ms4a7',
#   'Nkx2-2os',
#   'Arhgef15',
#   'Agt',
#   'Rinl',
#   'Kcnk13',
#   'Resp18',
#   'Sox10',
#   'Gxylt2',
#   'Zfp366',
#   'Tlx2',
#   'Rasip1',
#   'Jakmip2',
#   'Slpi',
#   'Ddo',
#   'Dnm3os',
#   'Cd37',
#   'Atp2b2',
#   'Cybb',
#   'Sla',
#   'Ngfr',
#   'Srpx2',
#   'Muc16',
#   'Dnah5',
#   'Ggt5',
#   'P2rx2',
#   'D430019H16Rik',
#   'Cd300lf',
#   'Meox2',
#   'Cyth4',
#   '9430020K01Rik',
#   'Ehd3',
#   'Gfra3',
#   'Cd79b',
#   '1810006J02Rik',
#   'Aldh1a2',
#   'Upk1b',
#   'Rasgrp1',
#   'Frrs1l',
#   'Clec2g',
#   'Nfatc4',
#   'Gem',
#   'Clip4',
#   'Lrrc4b',
#   '4930467D21Rik',
#   'Slc29a4',
#   'Ackr2',
#   'Fam169b',
#   'Gdap1',
#   'Etnppl',
#   'Cd40',
#   'Tespa1',
#   'Cd300lg',
#   '1810046K07Rik',
#   'Col24a1',
#   'Ccm2l',
#   'Slfn5',
#   'Slc35d3',
#   '1700111E14Rik',
#   'Blk',
#   'Baiap3',
#   'Ntf3',
#   'Sox5os4',
#   'Npr1',
#   'Clnk',
#   'Phactr3',
#   'Cd226',
#   'Nptxr',
#   'Rab7b',
#   'Ralyl',
#   'Mest',
#   'Trpm5',
#   'Slc8a3',
#   'St6galnac5',
#   'Srrm4',
#   'Snca',
#   'Gm13052',
#   'Stmn4',
#   'Bves',
#   'Htr3a',
#   'Rgs1',
#   'Apc2',
#   'Ngf',
#   'She',
#   'Galnt15',
#   'Upk3b',
#   'Shisa6',
#   'Cfap44',
#   'Gfpt2',
#   'Ms4a6b',
#   'Crmp1',
#   'Cd22',
#   'Abca9',
#   'Esam',
#   'Tmc3',
#   'Nuak1',
#   'Tspan32',
#   'Cd79a',
#   'Chst3',
#   'Gm12709',
#   'Wt1',
#   'Slc6a15',
#   'Gm43388',
#   'Gm15398',
#   'Srcin1',
#   'Kcna6',
#   'Agtr1a',
#   'Trpc4',
#   'Scn11a',
#   'Eya4',
#   'Robo4',
#   'Gm42439',
#   'Galnt16',
#   'Sh2d6',
#   'Slamf6',
#   'Cd53',
#   'Abcg3',
#   'Ntng1',
#   'Shc4',
#   'Celsr3',
#   'Scn9a',
#   '4930555F03Rik',
#   'Clec1a',
#   'Gimap3',
#   'Isl1',
#   'Fam163a',
#   'Itk',
#   'Cdh3',
#   'Medag',
#   'Lax1',
#   'Spock1',
#   'Kcnj3',
#   'A830019P07Rik',
#   'Erich3',
#   'Iigp1',
#   'Ndst4',
#   'Slfn3',
#   'Cd244',
#   'Sval3',
#   'Lcp2',
#   'Evc2',
#   'Nek10',
#   'Ccdc85a',
#   'C3',
#   'Faim2',
#   'Islr2',
#   'Rgs8',
#   'Miat',
#   'Ciita',
#   'Hs3st2',
#   'Ccdc129',
#   'Prdm6',
#   'Fgf7',
#   'Dscaml1',
#   'Grik4',
#   'Zfp831',
#   'Clstn2',
#   'Gimap4',
#   'Btnl9',
#   'Ipcef1',
#   'Klhl6',
#   'Stap1',
#   'Cd84',
#   'Scube2',
#   'Emb',
#   'Ildr2',
#   'Cd48',
#   'Fcer2a',
#   'Lgi4',
#   'Gm2245',
#   'Dcx',
#   'Chrna3',
#   'Entpd3',
#   'Soga3',
#   'Ms4a6c',
#   'Kcns3',
#   'Bdkrb2',
#   'Elavl2',
#   'Adam11',
#   'Gm14964',
#   'Runx3',
#   'Gm37459',
#   'Tacr1',
#   'Radil',
#   'Tm6sf1',
#   'Arsj',
#   'Gm38505',
#   'RP24-274B19.1',
#   'Disc1',
#   'Add2',
#   'Kcnmb2',
#   'Galr1',
#   'Nxph1',
#   'Kcnq4',
#   'Gm17276',
#   'Nckap1l',
#   'March4',
#   'Olfr78',
#   'Tmem179',
#   'Gm10863',
#   'Rgs13',
#   'Lrrn2',
#   'Pik3r5',
#   '4930419G24Rik',
#   'Cacng4',
#   'Tnfaip8l3',
#   'Fam184a',
#   'Fcrl1',
#   '9530059O14Rik',
#   'Gm15987',
#   'Ebf3',
#   'Gm43507',
#   'Sv2a',
#   'Bmx',
#   'Lbp',
#   'Gm11149',
#   'Nrg3os',
#   'Kcnc2',
#   'Scn5a',
#   'Ptpn22',
#   'Gria2',
#   'Vwa5b2',
#   'Myt1',
#   'Chat',
#   '4930578C19Rik',
#   'Slc10a6',
#   'Rfx6',
#   'Cr2',
#   'Col11a1',
#   'Rhoh',
#   'A430078G23Rik',
#   'Pax5',
#   'Btla'],
#  'Cycling_TA_1': ['Saa1',
#   'Rdh16',
#   'Trpm6',
#   'Sprr2a3',
#   'Ly6g',
#   'Slc40a1',
#   'Kcnip1',
#   'Enpp2',
#   'C1qtnf7',
#   'Sapcd2',
#   'Ddias',
#   'Gcg',
#   'Fgf10',
#   'Arhgap28',
#   'Avil',
#   'Ska1',
#   'Col4a6',
#   'Abcc8',
#   'Hpse2',
#   'Pdgfra',
#   'Pygl',
#   'Cdca5',
#   'St3gal1',
#   'Efemp1',
#   'Pla2r1',
#   'Chsy3',
#   'Fabp4',
#   'Man1c1',
#   'Igf1',
#   'Agt',
#   'Fam198b',
#   'Sytl5',
#   'Emb',
#   'Pappa',
#   'Vwf',
#   'Foxm1',
#   'Jam2',
#   'Adamts19',
#   'Ednra',
#   'Il16',
#   'Fbln5',
#   'Plvap',
#   'Esam',
#   'Ipcef1',
#   'Nuak1',
#   'Slfn2',
#   'Adamtsl3',
#   'Nebl',
#   'Arhgef15',
#   'Sh2d6',
#   'Psrc1',
#   'Rgs13',
#   'Cd247',
#   'Adgre1',
#   'F13a1',
#   'Gm44238',
#   'Rasip1',
#   'Iigp1',
#   'Kynu',
#   'Themis',
#   'Hck',
#   'Nlrc5',
#   '4930419G24Rik',
#   'Galnt15',
#   'Tnfaip8l3',
#   'Tm6sf1',
#   'Btk',
#   'Sla',
#   'Rinl',
#   'Ccm2l',
#   'Rasgrp1',
#   'Slfn5',
#   'Efcc1',
#   'Ms4a1',
#   'Kcnh6',
#   'Fam169b',
#   'Raet1e',
#   'Abcg3',
#   'B530045E10Rik',
#   'A430078G23Rik',
#   'Bmx',
#   'Cyth4',
#   'Gm15987',
#   'Stap1',
#   'Chst3',
#   'Aoah',
#   'Thsd1',
#   'Cd37',
#   'Cybb',
#   'Ciita',
#   'Txk',
#   'Lbp',
#   'Etnppl',
#   'Blk',
#   'Gm2245',
#   'Zfp831',
#   'Cd53',
#   'Pik3r5',
#   'Slc10a6',
#   'Tespa1',
#   'Cr2',
#   '4833422C13Rik',
#   'Nckap1l',
#   'Gm43388',
#   'Ms4a6b',
#   'Selplg',
#   'Disc1',
#   'Cd84',
#   'Clnk',
#   'Slfn3',
#   'Ms4a6c',
#   '4930578C19Rik',
#   'Gimap3',
#   'Lcp2',
#   'Klhl6',
#   'Itk',
#   'Slamf6',
#   'Cd244',
#   'Cd48',
#   'Cd226',
#   'Gimap4',
#   'Pax5',
#   'Runx3',
#   'Ptpn22',
#   'Btla',
#   'Rhoh'],
#  'Cycling_TA_2': ['Krt19',
#   'Tnr',
#   'Reg4',
#   'Cyp2f2',
#   '5330434G04Rik',
#   'Gabra3',
#   'Gm6086',
#   'P4hb',
#   'Kcnd2',
#   'Kcnh7',
#   'Ntng1',
#   'Entpd3',
#   'Scn2a1',
#   'Matk',
#   'Cyp2j9',
#   'Best2',
#   'Myt1l',
#   'Sult4a1',
#   'Avil',
#   'Btk',
#   'Ccdc85a',
#   'Clvs1',
#   'Muc1',
#   'Camk2a',
#   'Chd5',
#   'Ly6c1',
#   'Tspan6',
#   'Nuak1',
#   'Aldh1a3',
#   'Lck',
#   'Gja5',
#   'Ngfr',
#   'Ms4a1',
#   'Chrna3',
#   'Rit2',
#   'Cd247',
#   'Eef1a2',
#   'Plvap',
#   'Snap91',
#   'Clstn2',
#   'Slc5a7',
#   'Spock1',
#   'Gm9994',
#   'Itga11',
#   'Syt4',
#   'Thsd1',
#   'Pkib',
#   'Trpc4',
#   'Spon2',
#   'Zcchc12',
#   'Cnr1',
#   'Grid1',
#   'Kcnq3',
#   'Sv2a',
#   'Insm1',
#   'Vwf',
#   'Il16',
#   'Mapk8ip2',
#   'Zcchc18',
#   'Slc7a14',
#   'Dlgap2',
#   'Srcin1',
#   'Pi16',
#   'Cd180',
#   'Kcnmb2',
#   'Cadm3',
#   'Nxph1',
#   'Plat',
#   'C4b',
#   'Armc2',
#   'H2-DMb1',
#   'Igsf10',
#   'Rasip1',
#   'Shc4',
#   'Raet1e',
#   'Ppfia2',
#   'Esam',
#   'Snca',
#   'Fabp4',
#   'Aoah',
#   'Adgre1',
#   'Ggt5',
#   'St6galnac5',
#   'Arhgef15',
#   'Arhgap22',
#   'Ms4a4d',
#   'Gm17276',
#   'Kcnk3',
#   'Tbx3os1',
#   'Sla',
#   'Clip4',
#   'Dnajc6',
#   'Dmtn',
#   'Mest',
#   'Alox5',
#   'Rab7b',
#   'Fam169b',
#   'Chst3',
#   'Adam11',
#   'Kcna6',
#   'Rasgrp1',
#   'Gm42439',
#   'Syt14',
#   'Fgf7',
#   'Scube2',
#   'Gng4',
#   'Fcer2a',
#   'F13a1',
#   'Ushbp1',
#   'Agtr1a',
#   'Chat',
#   'Csf1r',
#   'Htra3',
#   'Col24a1',
#   'Nlrc5',
#   'Galnt16',
#   'Fam184a',
#   'Cd93',
#   'Slc8a3',
#   'Tespa1',
#   '4930467D21Rik',
#   'She',
#   'Lgi4',
#   'Zfp831',
#   'Trpm5',
#   'Tacr1',
#   'Tph1',
#   'Mfap5',
#   'Jam2',
#   '9430020K01Rik',
#   'Cyth4',
#   'Kcns3',
#   'Ntf3',
#   'Cd79b',
#   'Pygl',
#   'C3',
#   'Ebf3',
#   'Arsj',
#   'Ccdc129',
#   'Stap1',
#   'Nfatc4',
#   'Gm43388',
#   'Abca9',
#   'Ccm2l',
#   'Iigp1',
#   'Itk',
#   'Stxbp5l',
#   'Bves',
#   'Clnk',
#   'Cd300lg',
#   'Rarres2',
#   'Cybb',
#   'Ildr2',
#   'Dnah5',
#   'Ipcef1',
#   'Prdm6',
#   'Emb',
#   'Ptgis',
#   'Lrch2',
#   'Faxc',
#   'Slc6a17',
#   'Rgs1',
#   'Myt1',
#   'Chrdl1',
#   'Slfn2',
#   'Vwa5b2',
#   'Adamtsl3',
#   'Ms4a6b',
#   'Slfn5',
#   'Bdkrb2',
#   'Selplg',
#   'Cacng4',
#   'Rfx6',
#   'Gem',
#   'Cerkl',
#   'Igfbp6',
#   'Galnt15',
#   'Zfp366',
#   'Evc2',
#   'Tspan32',
#   'Olfr78',
#   'Ciita',
#   'Radil',
#   'Medag',
#   'Adamts19',
#   'Disc1',
#   'Abcg3',
#   'Kcnq4',
#   'Cd244',
#   'Lmx1a',
#   'Cd53',
#   'Cd48',
#   'Aebp1',
#   'Slfn3',
#   'Gm15987',
#   'Slamf6',
#   'Rgs13',
#   'Slc10a6',
#   'Col11a1',
#   'Cd22',
#   'Lbp',
#   'Gm11149',
#   'Gimap3',
#   'Sh2d6',
#   'Gimap4',
#   'Nova1',
#   'Tnfaip8l3',
#   'Efcc1',
#   'Cd84',
#   'Tm6sf1',
#   'Flt1',
#   'Klhl6',
#   'Nckap1l',
#   'Bmx',
#   'Lcp2',
#   '4930578C19Rik',
#   'Cldn5',
#   'Cr2',
#   'Gm43507',
#   'Gm2245',
#   'Cd226',
#   'Ly86',
#   'Pik3r5',
#   'Ms4a6c',
#   'Gm10848',
#   'Pax5',
#   'Slc38a11',
#   'Wdfy4',
#   'A430078G23Rik',
#   'Ptpn22',
#   'Rhoh',
#   'Runx3',
#   'Btla'],
#  'Enteroendocrine_1': ['Ctsb',
#   'Itm2b',
#   'Cdhr5',
#   'Acox1',
#   'Myo15b',
#   'Krt8',
#   'Cfl1',
#   'Nme7',
#   'Pkm',
#   'Pou2f3',
#   'Myt1l',
#   'Galnt18',
#   'Smim5',
#   '4930452B06Rik',
#   'Kynu',
#   'Cyp2f2',
#   'Armc2',
#   'Ar',
#   'Plvap',
#   'Eef1a2',
#   'Spib',
#   'Anxa13',
#   'Grik4',
#   'Pik3cd',
#   'Il1rl2',
#   'Tm6sf1',
#   'Gal3st2',
#   'Adgre1',
#   'Ptgis',
#   'Crispld1',
#   'Zfp9',
#   'Mgat5',
#   'Vav1',
#   '2010106E10Rik',
#   'Etnppl',
#   'Ndrg4',
#   'B530045E10Rik',
#   'Grhl3',
#   'Syt4',
#   'Rasip1',
#   'Gm42426',
#   'Ms4a1',
#   'Gcnt3',
#   'Myo1f',
#   'Tbx2',
#   'Cyp2d9',
#   'Zcchc12',
#   'Plcl2',
#   'Muc16',
#   'Ramp1',
#   'Abcb1b',
#   'St3gal6',
#   '4930552P12Rik',
#   'Pla2g7',
#   'Cyp2j9',
#   'Tspan6',
#   'Rad51b',
#   'Shf',
#   'H2-DMb1',
#   '1700111E14Rik',
#   'Ly6c1',
#   'Chat',
#   'Strip2',
#   'Fabp4',
#   'Btnl1',
#   'Megf10',
#   'Gm16233',
#   'Gjb5',
#   'C4b',
#   'Ccdc85a',
#   'Raet1e',
#   'Alox5',
#   'Disc1',
#   'Frem2',
#   'Abcc8',
#   'Slfn2',
#   'Fam212b',
#   'Rit2',
#   'Gm42439',
#   'Fam19a5',
#   'Vps13b',
#   'Sla',
#   'Cybb',
#   'F13a1',
#   'Lrrc26',
#   'Nlrc5',
#   'Gmds',
#   'Slc5a7',
#   'Mfap5',
#   'Foxa3',
#   'Tespa1',
#   'Gm15398',
#   'Htra3',
#   'Lgi4',
#   'Tacr1',
#   'Scg2',
#   'Rasgrp1',
#   'Selplg',
#   'Ipcef1',
#   'C1galt1',
#   'Ccm2l',
#   'Rab7b',
#   'Sval3',
#   'Ms4a4d',
#   'Btk',
#   'Scnn1g',
#   'Kcnn2',
#   '4833422C13Rik',
#   'Csf1r',
#   'Piwil4',
#   'Stap1',
#   'Casc4',
#   'Zfp366',
#   'C130071C03Rik',
#   'Gm12709',
#   'Tpcn2',
#   'Il16',
#   'Plat',
#   'Abcg3',
#   'Gabra3',
#   'Gm10863',
#   'C3',
#   '2310079G19Rik',
#   'Cyth4',
#   'Ms4a7',
#   'Aldh1a3',
#   'Pappa',
#   'Scn9a',
#   'Scube2',
#   'Clec3b',
#   'Fam169b',
#   'Galnt15',
#   'Hs3st2',
#   'Clnk',
#   'Gbp5',
#   'Sox10',
#   'Mest',
#   'Eya4',
#   'L3mbtl4',
#   'S1pr3',
#   'Slfn5',
#   'D430019H16Rik',
#   'Tmem179',
#   'Cr2',
#   'Blk',
#   'Ebf3',
#   'Gm1965',
#   'Gm43388',
#   'Cd79b',
#   'P2rx1',
#   'Rarres2',
#   'Adamtsl3',
#   'Rgs13',
#   'Radil',
#   'Aldh1a2',
#   'Thsd1',
#   'H2-Q7',
#   'Trpm5',
#   'Gimap3',
#   'Zfp831',
#   'Igsf10',
#   'Best2',
#   'Hck',
#   'Fam163a',
#   'Skap1',
#   'Snca',
#   'Ednra',
#   'Klhl6',
#   'Col6a4',
#   'Ly86',
#   'Ms4a6c',
#   'Efcc1',
#   'Cdh3',
#   'Cnr1',
#   'Aoc3',
#   'Gm14342',
#   'Chrm3',
#   'Rassf6',
#   'Mrc1',
#   '1810046K07Rik',
#   'Spink4',
#   'Chrdl1',
#   'Rasa4',
#   'Lcp2',
#   'Cd48',
#   'Cd300lg',
#   'Cd84',
#   'Ushbp1',
#   'Rgs1',
#   'Cd244',
#   'Ngfr',
#   'Ggt5',
#   'Srpx2',
#   'Pik3cg',
#   'Ndst4',
#   'Lrch2',
#   'Etv5',
#   'Wnt5a',
#   'Ciita',
#   'Kcna6',
#   'Smim3',
#   'St6galnac5',
#   'Tmprss5',
#   'Iigp1',
#   'Faim2',
#   'Chrna3',
#   'Slc10a6',
#   'Srcin1',
#   'Pid1',
#   '9430020K01Rik',
#   'Erg',
#   'Lbp',
#   'Gpm6a',
#   'Cd53',
#   'Runx3',
#   'Ahrr',
#   'Igfbp6',
#   'Fgf7',
#   'Fbln5',
#   'Nckap1l',
#   'A4gnt',
#   'Jam2',
#   'Antxrl',
#   'Cd226',
#   'Slfn3',
#   'Adam11',
#   '4930467D21Rik',
#   'Arhgap22',
#   'Speg',
#   'Prdm6',
#   'Stat4',
#   'Gimap4',
#   'Gm14344',
#   'Crtac1',
#   'Dnm3os',
#   'Slamf6',
#   'Hsd11b2',
#   'Ntf3',
#   'Slc4a7',
#   'Ehf',
#   'A630023A22Rik',
#   'Gm15987',
#   'Wdfy4',
#   'Gfpt2',
#   'Arhgef38',
#   'Kcnd2',
#   'Ccdc129',
#   'Slc8a3',
#   'Ralyl',
#   'Gm38505',
#   'Gm43603',
#   'Sox5os4',
#   'Nfatc4',
#   'Tbxas1',
#   'Aebp1',
#   'Chst3',
#   'Scn2a1',
#   'Itk',
#   'Dscaml1',
#   'Gm26889',
#   'Igf1',
#   'Ms4a6b',
#   'Cldn5',
#   'Clip4',
#   'Abca9',
#   'Arhgap30',
#   'Cd34',
#   'Fgf10',
#   'Pax5',
#   '9530059O14Rik',
#   'Medag',
#   'Gm1123',
#   'Cadm3',
#   'Lrrn2',
#   'Adamts19',
#   'Arsj',
#   'Ablim3',
#   'Dtx1',
#   'Col24a1',
#   'Astn1',
#   'Gpc3',
#   'Bmp6',
#   'Evc2',
#   '4930555F03Rik',
#   'Sh2d6',
#   'Gas1',
#   'Scn5a',
#   'Lrfn5',
#   'Btla',
#   'Cspg4',
#   'Gm2245',
#   'Fam198b',
#   'Fut8',
#   'Rhoh',
#   'Cdh5',
#   'Bdkrb2',
#   'Slc6a17',
#   'Jph1',
#   'Arap3',
#   'Bmx',
#   'Ppfia2',
#   'Pik3r5',
#   'Slc35f1',
#   'Pdgfra',
#   'Csf1',
#   'Galnt16',
#   '4930578C19Rik',
#   'Islr2',
#   'Pdia5',
#   'Stab1',
#   'Tie1',
#   'Hpse2',
#   'Kcnq3',
#   'Gnat3',
#   'Gm11149',
#   'Creb3l1',
#   'Scn7a',
#   'Kcnq4',
#   'Spdef',
#   'Sh3gl3',
#   'C1qtnf7',
#   'Prkcq',
#   'Nrg3os',
#   'Ptpn22',
#   'Gm20642',
#   'Col11a1',
#   'Enpp2',
#   'S1pr1',
#   'Agr2',
#   'Scube1',
#   'Ngf',
#   'Itga8',
#   'A430078G23Rik',
#   'Ikzf1',
#   'Cfh',
#   'Gm43507',
#   'Adgrl4',
#   'Bves',
#   'Rspo3',
#   'Angpt1',
#   'Pkhd1l1',
#   'Sybu',
#   'Abca8a',
#   'Kcnc2',
#   'Slc12a8',
#   'Trpc3',
#   'Ikzf3',
#   '4930578G10Rik'],
#  'Enteroendocrine_2': ['Slco2a1',
#   'Sepp1',
#   'Pde8b',
#   'Abcc3',
#   'Papss2',
#   'Tmem45b',
#   'Tgfbr3',
#   'Abca13',
#   'Speg',
#   'Faim2',
#   'Aoah',
#   'Adgrf5',
#   'Mtf2',
#   'Adm',
#   'Ccdc85a',
#   'Vwf',
#   'Ddo',
#   'B530045E10Rik',
#   'Kcns3',
#   'Lrrtm3',
#   'Ralyl',
#   '4930452B06Rik',
#   'Ggt1',
#   '2310079G19Rik',
#   'Cd44',
#   'Krt23',
#   'Tph1',
#   '4631405K08Rik',
#   'Gm16233',
#   'Medag',
#   'Wnt8b',
#   'Prph',
#   '1700041M19Rik',
#   'Cyp3a25',
#   'Pou2f3',
#   'Igfbp6',
#   'D930020B18Rik',
#   'Mest',
#   'Selplg',
#   'Ipcef1',
#   'Fam212b',
#   'Myo1f',
#   'Csf1r',
#   'Defb37',
#   'Angptl4',
#   'Shf',
#   'Tmem252',
#   'Spib',
#   'Ngfr',
#   'Dixdc1',
#   '9430020K01Rik',
#   'Plat',
#   '9030622O22Rik',
#   'Grik4',
#   '1700057G04Rik',
#   'Ntf3',
#   'P2rx2',
#   'Ms4a4d',
#   'Clnk',
#   'Upk1b',
#   'Fabp4',
#   'Grhl3',
#   'Gjb5',
#   'Htr3a',
#   'C130071C03Rik',
#   'Gpm6a',
#   'Muc1',
#   'Dnah5',
#   'Tmem179',
#   'C4b',
#   'Ptgis',
#   'Kcnn2',
#   'Musk',
#   'Aldh1a3',
#   'Scn2a1',
#   '4930552P12Rik',
#   'Fam184a',
#   'Cd248',
#   'Kynu',
#   'Ms4a6b',
#   'Gm10863',
#   'P4hb',
#   'Grin1',
#   'Raet1e',
#   'Aoc3',
#   'Shc4',
#   'Srrm4',
#   'Pirt',
#   'Mlip',
#   'Zfp831',
#   'Gdpd2',
#   'Clec3b',
#   'Chrna3',
#   'Clip4',
#   'Pik3cg',
#   'Ms4a7',
#   'Tbxas1',
#   'C3',
#   'Cd48',
#   'Adgrg2',
#   'Cybb',
#   'Hs3st4',
#   'Cd53',
#   'Tspan6',
#   'Gm43388',
#   '1810046K07Rik',
#   'Abcb1b',
#   'Btk',
#   'H2-Q7',
#   'Cyp2d9',
#   'Gbp5',
#   'Slfn3',
#   'Myt1l',
#   'Rab7b',
#   'Lrfn5',
#   'Ly6c1',
#   'Gm43603',
#   'Rgs1',
#   'Ushbp1',
#   'S1pr3',
#   'Crispld1',
#   'Strip2',
#   'Pou2f2',
#   'Plvap',
#   'St6galnac5',
#   'Scn5a',
#   'Gimap3',
#   'Cnr1',
#   'Meox2',
#   'Gm1965',
#   'Gm42426',
#   'Fcgr2b',
#   'Iigp1',
#   'Lgi4',
#   'Nckap1l',
#   'Ngf',
#   'Capn8',
#   'Cadm3',
#   'Piwil4',
#   'Slc6a17',
#   'Il1rl2',
#   'Tbx2',
#   'RP24-274B19.1',
#   'Alox5',
#   'Col6a4',
#   'Ecscr',
#   'Gm9994',
#   'Gm26510',
#   'Trp53inp1',
#   'Stat4',
#   'Abcg3',
#   'Cd34',
#   'Sla',
#   'Wnt5a',
#   'Lrrc26',
#   'Kcnc2',
#   'Sh2d7',
#   'Gm12709',
#   'Gcc2',
#   'She',
#   'Rasd2',
#   'Trpm5',
#   'Fgf7',
#   'Vps13b',
#   'Mrc1',
#   'Ptpn22',
#   'H2-DMb1',
#   'F13a1',
#   'Ggt5',
#   'Chst3',
#   'Htra3',
#   'Gm15998',
#   'Ppfia2',
#   'Pik3cd',
#   'Gm15398',
#   'Tespa1',
#   'Olfml2a',
#   'Fbln1',
#   'Cd84',
#   'Thsd1',
#   'Aebp1',
#   'Rarres2',
#   'Slfn5',
#   'Srcin1',
#   'Kcna2',
#   'Wdfy4',
#   'Rnf150',
#   'Ms4a6c',
#   'Spi1',
#   'Itk',
#   'Nlrc5',
#   '4930467D21Rik',
#   'Mfap5',
#   'Lcp2',
#   'Ednra',
#   'Btnl1',
#   'Vill',
#   'Lax1',
#   'Dtx1',
#   'Fstl4',
#   'Cidec',
#   'Scube2',
#   '4930555F03Rik',
#   'Ltbp3',
#   'Igsf10',
#   'Kcnd2',
#   'Frmd3',
#   'Hck',
#   'Clvs1',
#   'Gm15987',
#   'Gm14342',
#   'Smim3',
#   'Arhgap30',
#   'Ly86',
#   'A630023A22Rik',
#   'Srpx2',
#   'Cldn5',
#   'Pdk4',
#   '5033428I22Rik',
#   'Etnppl',
#   'Atp2a3',
#   'Gal3st2',
#   'Btnl9',
#   'Dscaml1',
#   'Kcnq3',
#   'Nrros',
#   'Chrdl1',
#   'Prkcq',
#   'Zfp366',
#   'Tie1',
#   'Dlg2',
#   'Csf1',
#   'Gm38505',
#   'Arsj',
#   'Spink4',
#   'Tacr1',
#   'S1pr1',
#   'Aldh1a2',
#   'Fam19a5',
#   'Adam11',
#   'Gas1',
#   'Gm14344',
#   'Ciita',
#   'Apba2',
#   'Hmha1',
#   'Rab3b',
#   'Abca9',
#   'Chat',
#   'Btla',
#   'P2rx1',
#   'Tpcn2',
#   'Cd244',
#   'Flt1',
#   'Pla2g7',
#   'Arhgap22',
#   'Igf1',
#   'Jam2',
#   'Runx3',
#   'Rasgrp3',
#   'Lbp',
#   'Anxa13',
#   'Scube1',
#   'A4gnt',
#   'Cfh',
#   'Trpc3',
#   'Kit',
#   'Tmprss5',
#   'Gfpt2',
#   'Tsc22d1',
#   'Itga8',
#   'Col14a1',
#   'Klhl6',
#   'Cspg4',
#   'Pald1',
#   'Tnfaip8l3',
#   'Kcna6',
#   'Hs3st2',
#   'Fbln5',
#   '9530059O14Rik',
#   'Ar',
#   'Cd300lg',
#   'Arhgap24',
#   'Bmx',
#   'Best2',
#   'Slc8a3',
#   'Rgs13',
#   'D5Ertd615e',
#   'Slc6a15',
#   'Rhoh',
#   'Efemp1',
#   'Bves',
#   'Gimap4',
#   'Gm6086',
#   'Col11a1',
#   'Insrr',
#   'Rassf6',
#   'Enpp2',
#   'Nrg3os',
#   'Evc2',
#   'Scn9a',
#   'Ablim3',
#   'Gm43507',
#   'Sval3',
#   'Gm20642',
#   'Sh2d6',
#   'Mgat5',
#   'Chsy3',
#   'Ramp1',
#   'Gnat3',
#   'Galnt16',
#   'Mir142hg',
#   'Antxrl',
#   'Gpc3',
#   'C1qtnf7',
#   'Adamtsl3',
#   'Frem2',
#   'Ebf3',
#   'Appl2',
#   'Kdr',
#   'Sox10',
#   'Arhgap28',
#   'Plet1os',
#   'Erg',
#   'Adamts19',
#   'Pappa',
#   'Rapgef3',
#   'Scn7a',
#   'Sox5os4',
#   'Stab1',
#   'Fam198b',
#   'Jph1',
#   'Ccdc80',
#   'Hpse2',
#   'Hsd11b2',
#   'Pkhd1l1',
#   'Nfatc4',
#   'Col4a6',
#   '4930578C19Rik',
#   'Arap3',
#   'Galnt15',
#   'Ccdc129',
#   'Angpt1',
#   'Foxa3',
#   'Cdh5',
#   'Mctp1',
#   'Slc35f1',
#   'Creb3l1',
#   'Sval1',
#   'Tbx3os1',
#   'Eepd1',
#   'Pdia5',
#   '9530036O11Rik',
#   'Abca8a',
#   'Gmds',
#   'Atoh1',
#   'Sybu',
#   'Col24a1',
#   'Pik3r5',
#   'Etv5',
#   'Pax5',
#   'Gpr20',
#   'Fgf10',
#   'Adamts17',
#   'C1galt1',
#   'Oit1',
#   'Rhbdl3',
#   'Tanc2',
#   'Plcb1',
#   'Gm2245',
#   'Sytl2',
#   'Pdgfra',
#   'Lepr',
#   'Kcnq4',
#   'Ikzf3',
#   'Ikzf1',
#   'Bdkrb2',
#   'Pla2r1',
#   'Plpp1',
#   'Prdm6',
#   'St6gal1',
#   'Gm1123',
#   'Galnt7',
#   'Adgrl4',
#   'A430078G23Rik',
#   'Art3',
#   'Galnt10',
#   'Sh3gl3',
#   '4930578G10Rik',
#   'Dnm3os',
#   'Rspo3',
#   'Ano7',
#   'Slc10a6',
#   'Spdef',
#   'Agr2',
#   'Slc12a8',
#   'Fut8',
#   'Astn1'],
#  'Fibroblast': ['Sycn',
#   'Ftl1',
#   'Atp12a',
#   'Slc40a1',
#   'Gjb5',
#   'Sval3',
#   'Dmtn',
#   'H2-Q7',
#   '4930552P12Rik',
#   'Gm9994',
#   'Cd180',
#   'Scnn1g',
#   'Sult4a1',
#   'Gm10848',
#   'Sh3gl3',
#   'Gm16183',
#   'Camk2a',
#   'Airn',
#   'Kcnn2',
#   'Acaa1b',
#   'Esam',
#   'Casc4',
#   'Gm13269',
#   'Zcchc12',
#   'Ndst4',
#   'Scg2',
#   'Gcg',
#   'Myo1f',
#   'Kcnq3',
#   'Mapk8ip2',
#   'Insm1',
#   'Jakmip2',
#   'Vill',
#   'Il17rb',
#   'Ggt1',
#   'Ina',
#   'Atp6v0a4',
#   'Sv2a',
#   'Best2',
#   'Chst3',
#   'Snhg11',
#   'Trpm5',
#   'Pik3cd',
#   'Krt23',
#   'Cd247',
#   'Ablim3',
#   'Rgs22',
#   'Faim2',
#   'Cdh8',
#   'Zcchc18',
#   '1700111E14Rik',
#   'Mettl21b',
#   'Tmem252',
#   'Mrc1',
#   'March4',
#   'Gm37459',
#   'Fam212b',
#   'Hs3st4',
#   'Slc5a7',
#   'Rsad2',
#   'Nalcn',
#   'Btk',
#   'Ly6g6d',
#   'Ms4a7',
#   'Abcg3',
#   'Rasip1',
#   'Matk',
#   'Kcna6',
#   'Trpv6',
#   'Cyp2d9',
#   'Ces2b',
#   'Gabbr2',
#   'P2rx2',
#   'Lcp2',
#   'Rasgrp1',
#   'Sla',
#   'Muc16',
#   'Syt4',
#   'Ace2',
#   'Shc4',
#   'Gdap1',
#   'Gm12709',
#   'Chd5',
#   'Cd53',
#   'Aoah',
#   'Gm15398',
#   'Nfasc',
#   'Resp18',
#   'Cdh3',
#   'Mlip',
#   'Crmp1',
#   'Rinl',
#   'Nckap1l',
#   'Ms4a6b',
#   'Cnr1',
#   'Raet1e',
#   'Megf10',
#   'Igf2bp1',
#   'Fcer2a',
#   'Tie1',
#   'Tmem179',
#   'Alox5',
#   'Nrg3os',
#   'Tnfaip8l3',
#   'Zfp831',
#   'Stap1',
#   'Lck',
#   'Spock1',
#   'Rgs1',
#   'Srrm4',
#   'Baiap3',
#   'C130071C03Rik',
#   'Miat',
#   '1810046K07Rik',
#   'Selplg',
#   'Zfp366',
#   'A630023A22Rik',
#   'Erich3',
#   'Adam11',
#   'Spink4',
#   'Cd48',
#   'Kynu',
#   'Fam163a',
#   'Cxxc4',
#   'Nkx2-2os',
#   'Clnk',
#   'Gfra3',
#   'Emb',
#   'Defb37',
#   'Clvs1',
#   'Fam169b',
#   'Chrna3',
#   'Kcnj3',
#   'Gm20642',
#   'Rit2',
#   'Ciita',
#   'Gm43388',
#   'Igsf21',
#   'Cldn5',
#   'Cfap44',
#   'Pkib',
#   '5330434G04Rik',
#   'Elavl2',
#   'Add2',
#   'Txk',
#   'Ccm2l',
#   'Wdfy4',
#   'Tespa1',
#   'Scn5a',
#   'Entpd3',
#   'Dtx1',
#   'Scn9a',
#   'Srcin1',
#   'Ipcef1',
#   'Cd244',
#   'Hck',
#   'Cyp3a25',
#   'Ms4a1',
#   'Blk',
#   'Kcnmb2',
#   '4930419G24Rik',
#   'Atcayos',
#   'Prkcq',
#   'Atp2b2',
#   'Ralyl',
#   'Btnl9',
#   'Atp2b3',
#   'Kcnh7',
#   'Hs3st2',
#   'Cd22',
#   'Rgs8',
#   'Slc29a4',
#   '4930578C19Rik',
#   'Gimap4',
#   'Nek10',
#   'Gimap3',
#   'Kcnc2',
#   'Cd226',
#   'Arhgap30',
#   'Slfn3',
#   'Dscaml1',
#   'Cd300lf',
#   'Pik3r5',
#   'Snca',
#   'Tnr',
#   'Gm10863',
#   'Ptpn22',
#   'Slamf6',
#   'Cyp4x1',
#   'Galr1',
#   'Gm2245',
#   'Tmprss5',
#   'Kcnh6',
#   'Gm15716',
#   'Dnah5',
#   'Myt1l',
#   'Soga3',
#   'Col11a1',
#   'Stat4',
#   'Slc26a4',
#   'Itk',
#   'Bves',
#   'Ly86',
#   'Runx3',
#   'Slc6a17',
#   'Nrros',
#   'Vwa5b2',
#   'Ushbp1',
#   'Cd84',
#   'Lrfn5',
#   'Trpc4',
#   'Btla',
#   'Bmx',
#   'Sh2d6',
#   'Tph1',
#   'Gnat3',
#   'Sox10',
#   'Olfr78',
#   'Kcnj6',
#   'Gria2',
#   'Syt14',
#   'Pax5',
#   '9530059O14Rik',
#   'Trpc3',
#   'Ccdc129',
#   'Stxbp5l',
#   'Dlgap2',
#   'Rgs13',
#   'Gm43603',
#   'Rhoh',
#   'Chat',
#   '1810006J02Rik',
#   'Myt1',
#   'Gm38505',
#   'A430078G23Rik',
#   'Rfx6',
#   'Antxrl',
#   'Slc38a11'],
#  'Glia': ['Itih5',
#   'mt-Atp6',
#   'Gm20400',
#   'Agt',
#   'Opcml',
#   'Crmp1',
#   'Slc5a7',
#   'Chrna3',
#   'Trpv6',
#   'Adgrg2',
#   'Defb37',
#   'Pygl',
#   'Arid5b',
#   'Ces2b',
#   'Spon2',
#   'BB365896',
#   'Aoc3',
#   'Ly6g6d',
#   'Bcam',
#   'Ly6c1',
#   'Cyp2c69',
#   'Gm20186',
#   'Smim5',
#   'Sval3',
#   '1700041M19Rik',
#   'Mfap5',
#   'F13a1',
#   'St6galnac5',
#   'Plpp1',
#   '2010106E10Rik',
#   'A330102I10Rik',
#   '1700111E14Rik',
#   'Scel',
#   'C3',
#   'Fabp4',
#   'Insm1',
#   'Ttr',
#   'Scgn',
#   'Spock1',
#   'Ms4a4d',
#   'Nfasc',
#   'Cnr1',
#   'Matk',
#   'Adgrg3',
#   '5330434G04Rik',
#   'Acaa1b',
#   'Ciita',
#   'A4gnt',
#   'Tbxas1',
#   '2310079G19Rik',
#   'Gdpd2',
#   'Cybb',
#   'Mtf2',
#   'Rab3b',
#   'Unc13c',
#   'Jakmip2',
#   'Ms4a7',
#   'Arg2',
#   'Krt23',
#   'Gm16183',
#   'Cxxc4',
#   'Tpcn2',
#   'Jph1',
#   'Gm11963',
#   'Speg',
#   'Adm',
#   'Gabbr2',
#   'Muc1',
#   'Gcg',
#   'Entpd3',
#   'Arhgef15',
#   'Medag',
#   'Dtx1',
#   'Pik3cd',
#   'Add2',
#   'Htra3',
#   'Raet1e',
#   'Aoah',
#   'Ms4a6b',
#   'Tmem252',
#   'Selplg',
#   'Grhl3',
#   'Ralyl',
#   'Gm9994',
#   'H2-DMb1',
#   'Mrc1',
#   'Rspo3',
#   'Galnt15',
#   'Clnk',
#   'Pyy',
#   'Ccdc149',
#   'Btk',
#   'Snap91',
#   'Cd93',
#   'Anxa13',
#   'Rgs1',
#   'Gm42426',
#   'Ugt8a',
#   'Ggt5',
#   'Fam169b',
#   'Gm14342',
#   'Sh2d7',
#   'Gxylt2',
#   'Csf1r',
#   'Gm1965',
#   'Elavl3',
#   'Myo1f',
#   'Ggt1',
#   '4930552P12Rik',
#   'Plvap',
#   'Clec3b',
#   'Slc8a3',
#   'Slfn2',
#   'Stap1',
#   'Cyp2d9',
#   'Kcnq3',
#   'Mettl21b',
#   'Spink4',
#   'Cd53',
#   'Ndst4',
#   'Vill',
#   'Col6a4',
#   'Igf1',
#   'Tnfsf15',
#   'Sis',
#   'Scn11a',
#   'Adgre1',
#   'Baiap3',
#   'Kcns3',
#   'Best2',
#   'Gpm6a',
#   'Esam',
#   '4930467D21Rik',
#   'Rasip1',
#   'Upk1b',
#   'Tnfrsf11b',
#   'Insrr',
#   'Hs3st4',
#   'P4hb',
#   'Sv2a',
#   'Piwil4',
#   'Cyp3a25',
#   'Gm16233',
#   'Gng4',
#   'Tespa1',
#   'Cyth4',
#   'Nek10',
#   'D930020B18Rik',
#   'Chsy3',
#   'Gria2',
#   'Slc6a17',
#   'Rasgrp1',
#   'Nrxn2',
#   'Plet1os',
#   'Gm2245',
#   'Acot4',
#   'Srpx2',
#   'Gm6086',
#   'Ms4a1',
#   'Cd300lf',
#   'Kcnh6',
#   'Pacsin1',
#   'Myt1l',
#   'Gm14344',
#   'A630023A22Rik',
#   'Pdgfra',
#   'Eepd1',
#   'Vwf',
#   'Sla',
#   'Tacr1',
#   'Arhgap30',
#   'Tnfaip8l3',
#   'Ccdc80',
#   'Tnr',
#   'Slc29a4',
#   'Emb',
#   'Cidec',
#   'Arhgap22',
#   'Muc16',
#   'Pde2a',
#   'Slc7a14',
#   'Stat4',
#   'Cd180',
#   'Kcnmb2',
#   'Nkx2-2',
#   'Tie1',
#   'P2rx1',
#   'Syt13',
#   'Cd300lg',
#   'Sh3gl3',
#   'Cd34',
#   'Abcg3',
#   'Scube2',
#   'Pou2f2',
#   'Clstn2',
#   'Hpse2',
#   'Gpr20',
#   'Arap3',
#   'Adamtsl3',
#   'Slit1',
#   'Atoh1',
#   'Col24a1',
#   'Trpm5',
#   'Pkib',
#   'Ace2',
#   'Bves',
#   'Fgf7',
#   'Cd48',
#   'Ipcef1',
#   '9530059O14Rik',
#   'Zfp831',
#   'Scn5a',
#   'Kcnh7',
#   'Cldn5',
#   'Dscaml1',
#   'Bmx',
#   'Syt14',
#   '1810046K07Rik',
#   'Gm15987',
#   'Nxph1',
#   'Wdfy4',
#   'Slfn3',
#   'Ptgis',
#   'Ar',
#   'Dscam',
#   'Tpd52l1',
#   'Nrros',
#   '4930555F03Rik',
#   'Lrfn5',
#   'Pla2r1',
#   'Dlgap2',
#   'Slfn5',
#   'Ppfia2',
#   'Prdm6',
#   'Clec1a',
#   'Gimap3',
#   'Isl1',
#   'Klhl6',
#   'Gimap4',
#   'Cd22',
#   'Hs3st2',
#   'Olfr78',
#   'Kcnj6',
#   'Spi1',
#   'Chat',
#   'Trpc4',
#   'Gjb5',
#   'Alox5',
#   'Adamts19',
#   'Hck',
#   'Nckap1l',
#   'Pik3cg',
#   'Klf12',
#   'Ackr2',
#   'Bdkrb2',
#   'S1pr1',
#   'Blk',
#   'Stab1',
#   'Sh2d6',
#   'Trpc3',
#   'Cdh5',
#   'Gm14964',
#   'Flt1',
#   'Gm43388',
#   '4930578G10Rik',
#   '1810006J02Rik',
#   'Vwa5b2',
#   '4930578C19Rik',
#   'Ushbp1',
#   'Abcc8',
#   'Ccm2l',
#   'Frem2',
#   'Slamf6',
#   'Ms4a6c',
#   'Cbfa2t3',
#   'Tmem108',
#   'Col4a6',
#   'Cfh',
#   'Ccdc129',
#   'Btla',
#   'Cd244',
#   'Snhg11',
#   'Galr1',
#   'Gm43603',
#   'Adgrl4',
#   'Kynu',
#   'Rgs13',
#   'Atcayos',
#   'Ly86',
#   'Erg',
#   'Ptpn22',
#   'Arhgap28',
#   'Runx3',
#   'Tph1',
#   'Stxbp5l',
#   'Lmx1a',
#   'Pik3r5',
#   'Angpt1',
#   'Antxrl',
#   'Fgf10',
#   'March4',
#   'C1qtnf7',
#   'Skap1',
#   'Myt1',
#   'Pax5',
#   'Cd84',
#   'Rhoh',
#   'Cyp4x1',
#   'Ablim3',
#   'A430078G23Rik',
#   'Gnat3',
#   'Ikzf3',
#   'Pkhd1l1',
#   'Slc12a8',
#   'Gimap8',
#   'Gm10848',
#   'Rfx6',
#   'Gm13269',
#   'Slc38a11'],
#  'Goblet': ['Slc13a2',
#   'Emp1',
#   'Mettl7b',
#   'Rps29',
#   'B4galnt3',
#   'Bsg',
#   'Gipc2',
#   'Spdef',
#   'Cidec',
#   'Ntm',
#   'Ppp1r14c',
#   'P2rx1',
#   'Jam2',
#   'Itga11',
#   'Runx1',
#   'Lypd6b',
#   'Pkib',
#   'Il1rl2',
#   'Nlrc5',
#   'Slc18a1',
#   'Gm43126',
#   'Aldh1a3',
#   'Krt23',
#   'Pi16',
#   'Gm43634',
#   'Rapgef3',
#   'Cyp2c69',
#   'H2-DMb1',
#   'Cerkl',
#   'Dach2',
#   'Ehf',
#   'Kynu',
#   'Arhgef15',
#   'Sgsm1',
#   'Plvap',
#   'Cybb',
#   'Kcnmb2',
#   'Reg4',
#   'Tnfsf15',
#   'Mrc1',
#   'Cdh8',
#   'Gm16183',
#   'Spon2',
#   'Slfn5',
#   'Spock1',
#   'Mfap5',
#   'Ms4a6c',
#   'Igsf10',
#   'Zfp831',
#   'Elavl2',
#   'Fabp4',
#   'Aoah',
#   'Cyp2j9',
#   'Btnl1',
#   '9430020K01Rik',
#   'Tmprss5',
#   'Armc2',
#   'Clec3b',
#   'Stap1',
#   'Myt1',
#   'Add2',
#   'Fam212b',
#   '9030622O22Rik',
#   '4930452B06Rik',
#   'Selplg',
#   'Gm43603',
#   'Lmx1a',
#   'Kcnk3',
#   'Cd300lg',
#   'Plekhd1os',
#   'Scn11a',
#   'Igsf21',
#   'Cyp2f2',
#   'Cr2',
#   'Alox5',
#   'Ms4a6b',
#   'Arhgap22',
#   'Jakmip2',
#   'Atp6v0a4',
#   'Ms4a4d',
#   'Gm26510',
#   'Ggt5',
#   'Disc1',
#   '4930578C19Rik',
#   'Chd5',
#   'Scube1',
#   'Tnfrsf11b',
#   'Gm14342',
#   'Pappa2',
#   'Bmp6',
#   'Gm15398',
#   'Apc2',
#   'Matk',
#   'Cux2',
#   'Nek10',
#   'Wdfy4',
#   'Clnk',
#   'Tspan6',
#   '2410018L13Rik',
#   'Ace2',
#   'Zdhhc14',
#   'Nxph1',
#   '4930419G24Rik',
#   'Vwa5b2',
#   'Grik4',
#   'St3gal1',
#   'Tbx2',
#   'Slc29a4',
#   'Sh2d7',
#   'Ly86',
#   'Ccm2l',
#   'Lck',
#   'Col14a1',
#   'Il16',
#   'Ciita',
#   'Plat',
#   'Shc4',
#   'Cd34',
#   'C4b',
#   'Stk32a',
#   'Cd53',
#   'Ildr2',
#   'Gm15987',
#   'Ntf3',
#   'Galnt15',
#   'Btla',
#   'Nuak1',
#   'Kcna6',
#   'Cacng4',
#   'Nckap1l',
#   'Ecscr',
#   'Gem',
#   'Cdh3',
#   'Rfx6',
#   'Stxbp5l',
#   'Arg2',
#   'Itpr1',
#   '4930467D21Rik',
#   'Mir142hg',
#   'Myo1f',
#   'Clstn2',
#   'Calcb',
#   'Otud7a',
#   'Arhgap30',
#   'Ina',
#   'Cyth4',
#   'Bves',
#   'Piezo2',
#   'Galnt16',
#   'Iigp1',
#   'Fgf7',
#   'Fam169b',
#   'Esam',
#   'Fut8',
#   'Nags',
#   'Nalcn',
#   'Gm10863',
#   'Emb',
#   'Galr1',
#   'Clip4',
#   'Ushbp1',
#   'Vav1',
#   'Slc35d3',
#   'Adgrg2',
#   'Pou2f2',
#   'Lcp2',
#   'Abca9',
#   'She',
#   'Rps6ka2',
#   'Srrm4',
#   'Dnah5',
#   'Cldn5',
#   'Ccdc85a',
#   'Fbln5',
#   'Slc10a6',
#   'Tlx2',
#   'H2-Q7',
#   '1700111E14Rik',
#   'Lrrc4b',
#   'Alpi',
#   'Cd84',
#   'Btnl9',
#   'Ralyl',
#   'Stat4',
#   'Nrros',
#   'Eya4',
#   'Tnr',
#   'Gm14344',
#   'Arsj',
#   'Csgalnact1',
#   'Agtr1a',
#   'Fcer2a',
#   'Muc16',
#   'Flt1',
#   'Tmem252',
#   'RP24-274B19.1',
#   'Htr3a',
#   'Col24a1',
#   'Gm17276',
#   'Lbp',
#   'Rhoh',
#   'Htra3',
#   'Scgn',
#   'Chrdl1',
#   'Cdh5',
#   'Elmod1',
#   'Tnfaip8l3',
#   'Rarres2',
#   'Cbln2',
#   'C3',
#   'Klhl6',
#   'Trpc4',
#   'Slc6a15',
#   'Ipcef1',
#   'Rgs1',
#   'Grid1',
#   'Ar',
#   'Nfatc4',
#   'Aldh1a2',
#   'Fbln1',
#   'A330102I10Rik',
#   'Pdgfra',
#   'Adamts19',
#   'Strip2',
#   'S1pr1',
#   'Mettl21b',
#   'BB365896',
#   'Mapk8ip2',
#   'Csf1',
#   'Camk2a',
#   'Fam163a',
#   'Gimap4',
#   'Slc35f1',
#   'Ccdc129',
#   'Nptxr',
#   'Gimap3',
#   'Ica1',
#   'Upk1b',
#   'Cplx2',
#   'Pax5',
#   'Snca',
#   'Stab1',
#   'Ndst4',
#   'Igf1',
#   'Dlgap2',
#   'Tm6sf1',
#   'Kcnn2',
#   'Gabra3',
#   'Slc17a9',
#   'Dscaml1',
#   'Col4a6',
#   'Soga3',
#   '5330434G04Rik',
#   'Skap1',
#   'Erg',
#   'Ptgis',
#   'Upk3b',
#   'Lgi4',
#   'Fam105a',
#   'Gpc3',
#   'Igfbp6',
#   'Scube2',
#   'Gm1965',
#   'Ccdc80',
#   'Gng4',
#   'Unc13c',
#   'Myt1l',
#   'Rasip1',
#   'Dtx1',
#   'D430019H16Rik',
#   'Gm11149',
#   'Ednra',
#   'Cacnb4',
#   'Pik3cg',
#   'Slc8a3',
#   'Resp18',
#   'Gm42439',
#   'Gas1',
#   'Radil',
#   'Nkx2-2',
#   'Myl1',
#   '4631405K08Rik',
#   'Fstl5',
#   'Tie1',
#   'Cspg4',
#   'Kcnj3',
#   'Tpcn2',
#   'Zcchc18',
#   'Faim2',
#   'Atp2b2',
#   'Efcc1',
#   'Crmp1',
#   'Gimap8',
#   'Hs3st2',
#   'Adam11',
#   'Crtac1',
#   'Pald1',
#   'Pdk4',
#   'Frem2',
#   'Sh3gl3',
#   'Hmha1',
#   'Frrs1l',
#   'Ikzf1',
#   'Adgrl4',
#   'Eef1a2',
#   'March4',
#   'Speg',
#   'Arap3',
#   'Slc4a7',
#   'Pik3cd',
#   'Pappa',
#   'Mest',
#   'Syt13',
#   'Aebp1',
#   'St6galnac5',
#   'Ntng1',
#   'Tubb2b',
#   'Aoc3',
#   'Wnt5a',
#   'Phactr3',
#   'Rit2',
#   'Lrch2',
#   'Prdm6',
#   'Gm2245',
#   'Ikzf3',
#   'Gfra1',
#   'Cfh',
#   'Nrg3os',
#   'P2rx2',
#   'Nova1',
#   'Cd300lf',
#   'Scn2a1',
#   'Ltbp3',
#   'Ehd3',
#   'Ptpn22',
#   'Fam198b',
#   'Efemp1',
#   'Eepd1',
#   'Lepr',
#   'Gabrb3',
#   'Syt14',
#   'Dnajc6',
#   'Hmgn3',
#   'Sult4a1',
#   'Rgs13',
#   'Clvs1',
#   'Jph1',
#   'Tbx3os1',
#   'Ebf3',
#   'Entpd3',
#   'Enpp2',
#   'Ugt8a',
#   'D5Ertd615e',
#   'Hap1',
#   'Cxxc4',
#   'Hpse2',
#   'Dmtn',
#   'Snap91',
#   'Prkcq',
#   'Faxc',
#   'Adgrg3',
#   'Lrrn2',
#   'Medag',
#   'Man1c1',
#   'Bmx',
#   'Tmem179',
#   'Pdxdc1',
#   'Kcnq4',
#   'Scn9a',
#   '4833422C13Rik',
#   'Fam184a',
#   'Gm12709',
#   'Tacr1',
#   'Rasgrp3',
#   'Cadm3',
#   'Evc2',
#   'Piwil4',
#   'Fgf10',
#   'Abca8a',
#   'Adamtsl3',
#   'Ccdc149',
#   'Kdr',
#   'Gcg',
#   'Bdkrb2',
#   'Kcnd2',
#   'Ngfr',
#   'Pygl',
#   '4930555F03Rik',
#   'Pik3r5',
#   'Plpp1',
#   'Slc6a17',
#   'Srcin1',
#   'Angptl4',
#   'Gpm6a',
#   'Hck',
#   'Nfasc',
#   'C1qtnf7',
#   'Trpm5',
#   'Zcchc12',
#   'Elavl3',
#   'Arhgap28',
#   'Art3',
#   'Apba2',
#   'Scn7a',
#   'Scn5a',
#   'Runx3',
#   'Lrfn5',
#   'Nebl',
#   'Xkr4',
#   'Pla2r1',
#   'Snhg11',
#   'Pkhd1l1',
#   'Scg2',
#   'Sv2a',
#   'Slc5a7',
#   'Chat',
#   'Trpc3',
#   'Itga8',
#   'Dync1i1',
#   'Chrna3',
#   'Pirt',
#   'Sh2d6',
#   'Gabre',
#   'Gm42426',
#   'Kcnn3',
#   'Angpt1',
#   'Gria2',
#   'Zfp9',
#   'Tmem108',
#   'Fam19a5',
#   'Gdap1',
#   'A430078G23Rik',
#   'Kit',
#   'Ablim3',
#   'Nrxn2',
#   'Gm10848',
#   'Astn1',
#   'Smim3',
#   'Chsy3',
#   'Cbfa2t3',
#   '4930578G10Rik',
#   'Cnr1',
#   'Dzip1l',
#   'Vnn1',
#   'Abcc8',
#   '9530059O14Rik',
#   'Kcnq3',
#   'Tpd52l1',
#   'Slc7a14',
#   'Creb3l1',
#   'Fstl4',
#   'Col11a1',
#   'Sybu',
#   'Ppfia2',
#   'Rspo3',
#   'Cyp3a44',
#   'Sis',
#   'Tanc2',
#   'Insrr',
#   'Kcnc2',
#   'St18',
#   'Lrrtm3',
#   'Adamts3',
#   '5330417C22Rik',
#   'Palmd',
#   'Pdia5',
#   'Slc12a8',
#   '9530036O11Rik',
#   'D930020B18Rik',
#   'Cyp3a25',
#   'Gm13832',
#   'Rhbdl3',
#   'Gm13269',
#   'A4gnt',
#   'Syt4',
#   'Pacsin1',
#   'Acaa1b',
#   'Defb37',
#   'Adamts17',
#   'Plet1os'],
#  'Lymphatic': ['Muc3',
#   'Gsdmc4',
#   'Gas1',
#   'Ndrg4',
#   'Cyp2c69',
#   'Il1rl2',
#   'Zfp9',
#   'Ly6g6d',
#   'Prickle2',
#   'Cux2',
#   'Chd5',
#   'Spon2',
#   'Syt4',
#   'Htra3',
#   'P4hb',
#   'Zdhhc14',
#   'Lck',
#   'Agt',
#   'Matk',
#   '2310079G19Rik',
#   'Aldh1a3',
#   'Il17rb',
#   'Crispld1',
#   'Crmp1',
#   'Hsd11b2',
#   'Cr2',
#   'Gng4',
#   'Atp6v0a4',
#   'Gem',
#   'Cnr1',
#   'Camk2a',
#   'Chrna3',
#   'Pik3cd',
#   'Csf1r',
#   'Arhgap28',
#   'Rarres2',
#   'Gm12381',
#   'Abca13',
#   'Igf1',
#   'Faim2',
#   'Cdh8',
#   'Cybb',
#   'Vwf',
#   'Add2',
#   'Ace2',
#   'Itga11',
#   'Btk',
#   'Rgs1',
#   'Muc1',
#   'Pde2a',
#   'Krt23',
#   'Enpp2',
#   'Kcnj3',
#   'Cd247',
#   'H2-DMb1',
#   'Adgre1',
#   'Gabra3',
#   'Nkx2-2os',
#   'Alpi',
#   'Fam163a',
#   'Gjb5',
#   'Ms4a4d',
#   'Chrdl1',
#   'Vill',
#   'Rasgrp1',
#   'Wif1',
#   'Avil',
#   'Abcb1b',
#   'Slc5a7',
#   'Rit2',
#   'Pappa2',
#   'Tmem151a',
#   'Ciita',
#   'Mfap5',
#   'Tbx2',
#   'Cd180',
#   'Cadm3',
#   'Pik3cg',
#   'Gfra3',
#   'Armc2',
#   'Ptgis',
#   'Trpv6',
#   'Unc13c',
#   'Nfatc4',
#   'Nova1',
#   'Gm14344',
#   'Cd53',
#   'Sla',
#   'Jakmip2',
#   'Tnfrsf11b',
#   'Pla2g7',
#   'Fam169b',
#   'Clvs1',
#   'Jam2',
#   'Gabbr2',
#   'C4b',
#   '1700111E14Rik',
#   'Aoah',
#   'Ralyl',
#   'Kcnq3',
#   'Cyp2j9',
#   'Zfp366',
#   'Muc16',
#   'Sv2a',
#   'Cyp2d9',
#   'Medag',
#   'Rgs22',
#   'Rhoh',
#   'Musk',
#   'Ces2b',
#   '5330434G04Rik',
#   '1700041M19Rik',
#   'Fstl5',
#   'Myt1l',
#   'Ms4a7',
#   'Klhl6',
#   'Spock1',
#   'Wdfy4',
#   'Kcnj6',
#   'Nckap1l',
#   'Sh2d7',
#   'Cd22',
#   'Upk1b',
#   'Ildr2',
#   'Ndst4',
#   'Slc7a14',
#   'Ipcef1',
#   'Kcna6',
#   'Cemip',
#   'Ms4a1',
#   'Pdk4',
#   'Col4a6',
#   'Elavl2',
#   'Adgrg2',
#   'Bdkrb2',
#   'Gria2',
#   'Speg',
#   'Ppfia2',
#   '4930467D21Rik',
#   'Srrm4',
#   'Hs3st4',
#   'Cyp3a44',
#   'Atp2b2',
#   'Txk',
#   'Snhg11',
#   'Cfap44',
#   'Ntf3',
#   'Baiap3',
#   'Soga3',
#   'Stap1',
#   'Gm16233',
#   'Ddo',
#   'Chst3',
#   'Igf2bp1',
#   'Cacng4',
#   'Raet1e',
#   'Entpd3',
#   'Defb37',
#   'Acaa1b',
#   'Shc4',
#   'Pnpla3',
#   'St6galnac5',
#   'Kcnk3',
#   'Snap91',
#   'Tmem252',
#   'Pkib',
#   'Phactr3',
#   'Cerkl',
#   'Ggt1',
#   'Tnr',
#   'Srcin1',
#   'Galnt16',
#   'Adam11',
#   'Gm15987',
#   'Alox5',
#   'Selplg',
#   'Itk',
#   'Trpm5',
#   'Tespa1',
#   'Kcns3',
#   'Abca9',
#   'Gimap3',
#   'Scn9a',
#   'Gm15398',
#   'Igsf21',
#   'Cxxc4',
#   'March4',
#   'Fgf7',
#   'Pax5',
#   'Ms4a6b',
#   'Clip4',
#   'Scube2',
#   'Ms4a6c',
#   'A630023A22Rik',
#   '9530059O14Rik',
#   'Kcnc2',
#   'Eya4',
#   'Emb',
#   'Nek10',
#   'Gm37459',
#   'Pax6os1',
#   'Arhgap22',
#   'Gm43388',
#   'Miat',
#   'Isl1',
#   'Agtr1a',
#   'Nxph1',
#   'Dnah5',
#   'Gm10863',
#   'Cd48',
#   'Grik4',
#   'Cd300lf',
#   'Kcnh6',
#   '1700057G04Rik',
#   'C130071C03Rik',
#   'Pdgfra',
#   '4930419G24Rik',
#   'Gdpd2',
#   'Dscaml1',
#   'Clnk',
#   'Syt14',
#   'Tacr1',
#   'Clstn2',
#   'Gm42439',
#   'Lcp2',
#   'Lrfn5',
#   'Prdm6',
#   'Ly86',
#   'Arhgap30',
#   'Cd84',
#   'Kynu',
#   'Vwa5b2',
#   'Megf10',
#   'Kcnq4',
#   'Cd244',
#   'Cyp3a25',
#   'Gm17276',
#   'Gm20594',
#   'Slc6a17',
#   'Tmprss5',
#   'Bves',
#   'Runx3',
#   'Ntng1',
#   'Rgs13',
#   'Hck',
#   'Dlgap2',
#   'Btla',
#   'Ccdc129',
#   'Dnajc6',
#   'Tbx3os1',
#   'Gm43603',
#   'Pygl',
#   'Tph1',
#   'Col24a1',
#   'Slc8a3',
#   'Sox5os4',
#   'Gm20642',
#   'Lmx1a',
#   'Chat',
#   'RP24-274B19.1',
#   'Stat4',
#   '1810006J02Rik',
#   'Pik3r5',
#   'Sh2d6',
#   'Adamts19',
#   'Nrg3os',
#   'Olfr78',
#   'Gnat3',
#   'Trpc4',
#   'Gm11149',
#   'Myt1',
#   'Ednra',
#   'Ptpn22',
#   'Gm2245',
#   'Gm38505',
#   'A430078G23Rik',
#   'Gm10848',
#   'Col11a1',
#   'Slc38a11',
#   'Rfx6',
#   'Antxrl'],
#  'Macrophage': ['Actb',
#   'Prdx6',
#   'Ahnak',
#   'Tgm3',
#   'Saa1',
#   'Slc37a2',
#   'Pde7a',
#   'mt-Co3',
#   'Sycn',
#   'Tmem37',
#   'Hoxb13',
#   'H2-K1',
#   'Slc40a1',
#   'S100a6',
#   'Aldh2',
#   'Ftl1',
#   'Gpx1',
#   'Cmtm8',
#   'Csf1',
#   'Crispld1',
#   'Slc5a7',
#   'Adam11',
#   'Adm',
#   'mt-Nd1',
#   'BB365896',
#   'Bcam',
#   'Prph',
#   'Ecscr',
#   'Esam',
#   'Zbtb16',
#   'Kcnh6',
#   'Gimap8',
#   'Chsy3',
#   'Gal3st2',
#   'Tnr',
#   'Aebp1',
#   'Smim5',
#   'Synpr',
#   'Mfap5',
#   'Tspan6',
#   'Sult4a1',
#   'Gm12709',
#   'Crmp1',
#   'Fbln5',
#   '9430020K01Rik',
#   'Aldh1a3',
#   'Tnfsf15',
#   'Skap1',
#   'Srcin1',
#   'Syt4',
#   'Mtf2',
#   'Cd34',
#   'Plat',
#   'Adgrg2',
#   'Zcchc18',
#   'Shc4',
#   'Fgf7',
#   'Ccm2l',
#   'Gm16233',
#   'P2rx1',
#   'Ace2',
#   'Cux2',
#   'Nalcn',
#   'Tubb2b',
#   'Cadm3',
#   'Ramp1',
#   'Rrbp1',
#   'Rep15',
#   'Atp6v0a4',
#   'Fam198b',
#   'St3gal6',
#   'Gdap1',
#   'Anxa13',
#   'Cnr1',
#   'Speg',
#   'Cyp2d9',
#   'Gjb5',
#   'A330102I10Rik',
#   'Gm11963',
#   '1700111E14Rik',
#   'Mest',
#   'Gm43634',
#   'Dnajc6',
#   'Tsc22d1',
#   'Fam221a',
#   'Gm14342',
#   'Dscaml1',
#   'Ndst4',
#   'Aoc3',
#   'Ccdc85a',
#   '1700041M19Rik',
#   'Arg2',
#   '4930552P12Rik',
#   'Muc16',
#   'Ccdc80',
#   'Trpv6',
#   'Clip4',
#   'Rasip1',
#   'Unc13c',
#   'Nkx2-2os',
#   'Srrm4',
#   '5330434G04Rik',
#   'Hsd11b2',
#   'Ushbp1',
#   '4930467D21Rik',
#   'Shf',
#   'Tnfrsf11b',
#   'Chrdl1',
#   'Musk',
#   'Kcnj3',
#   'Gng4',
#   'Itga11',
#   'Tie1',
#   'Syt13',
#   'Cdh3',
#   'March4',
#   'Gabra3',
#   'Cntn1',
#   'Piwil4',
#   'Gm1965',
#   'Arhgef15',
#   'Kcns3',
#   'Rit2',
#   'Chrna3',
#   'Tmem151a',
#   'Jam2',
#   'Grid1',
#   'Hepacam2',
#   'Igsf21',
#   'Ralyl',
#   'Cdh8',
#   'Fam163a',
#   'Hs3st4',
#   'Kcna6',
#   'Cyp2j9',
#   'Gm37459',
#   'Prdm6',
#   'Cplx2',
#   'Igf2bp1',
#   'Medag',
#   '4930419G24Rik',
#   'P4hb',
#   'Ggt1',
#   'Gas1',
#   'Cidec',
#   'Ebf3',
#   'Thsd1',
#   'Jakmip2',
#   'Tmem252',
#   'Gdpd2',
#   'Ntm',
#   'Gm14344',
#   'Kcnj6',
#   'Gxylt2',
#   'Plet1os',
#   'Prkcq',
#   'Acot4',
#   'Ces2b',
#   'Kcnk3',
#   'Scube2',
#   'Defb37',
#   'Cfap44',
#   'Igsf11',
#   'Fstl5',
#   'Bdkrb2',
#   'Ngf',
#   'Upk1b',
#   'Arsj',
#   'Amn',
#   'Lrfn5',
#   'Tacr1',
#   'Kcnc2',
#   'Muc1',
#   'Dtx1',
#   'Trpm5',
#   'Clstn2',
#   'D930020B18Rik',
#   'Sytl5',
#   'Col24a1',
#   'Ptgis',
#   'Dnah9',
#   'Pdk4',
#   'Lrrc26',
#   'Lypd6b',
#   'Cspg4',
#   'Rab27a',
#   'Pdgfra',
#   'Rab3b',
#   'Elavl3',
#   'Phactr3',
#   'Sv2a',
#   'Alpi',
#   'Gpr20',
#   'Myt1l',
#   'Ar',
#   'Plpp1',
#   'Sox5os4',
#   'Pax6os1',
#   'Frmd3',
#   'A630023A22Rik',
#   'Slc29a4',
#   'Dmtn',
#   'Wnt5a',
#   'Rgs22',
#   'Ntng1',
#   'C130071C03Rik',
#   'Otud7a',
#   'Lrrn2',
#   'Slc7a14',
#   'Efemp1',
#   'Gm42439',
#   'Enpp2',
#   'Bmp5',
#   'Nrxn2',
#   'Galnt15',
#   'Scn9a',
#   'Kcnq3',
#   'A4gnt',
#   'Nfatc4',
#   'Galnt16',
#   'Art3',
#   'Ppfia2',
#   'Snhg11',
#   'Kcnh7',
#   'Evc2',
#   'Dnm3os',
#   'Kcnmb2',
#   'Cdh5',
#   'Cxxc4',
#   'Dlg2',
#   'Adamtsl3',
#   'Lbp',
#   'Appl2',
#   'Tph1',
#   'Baiap3',
#   'Atp2c2',
#   'Slc18a1',
#   'Olfr78',
#   'Megf10',
#   'Snca',
#   'Insrr',
#   'Gabre',
#   '4930578C19Rik',
#   'Agtr1a',
#   'Gm15398',
#   'Cemip',
#   'Nkx2-2',
#   'Erg',
#   'Atoh1',
#   'Fam184a',
#   'Dgki',
#   'Ccdc129',
#   'Scn7a',
#   'Pacsin1',
#   'Zfp9',
#   'Ppp1r14c',
#   'Adgrg3',
#   'Sox10',
#   'Vwa5b2',
#   'Ntf3',
#   'Rgs13',
#   'Acaa1b',
#   'Isl1',
#   'Apba2',
#   'Jph1',
#   'Xkr4',
#   'Bves',
#   'Gm16183',
#   'Pappa',
#   'Sh3gl3',
#   'Gpc3',
#   'Clvs1',
#   'Ednra',
#   'Gm20642',
#   'Plet1',
#   'Gm1123',
#   'Lrch2',
#   'Grik4',
#   'Kdr',
#   'Kit',
#   'Cldn5',
#   'Scn2a1',
#   'Soga3',
#   'Rapgef3',
#   'Wif1',
#   'Btnl1',
#   'Gabrb3',
#   'Lepr',
#   'Astn1',
#   'Scube1',
#   'Gpm6a',
#   'Scnn1g',
#   'Ddo',
#   'Syt14',
#   'Map6',
#   'Frem2',
#   'Kcnd2',
#   'Adamts19',
#   'Kcnq4',
#   'Slc6a17',
#   'Nxph1',
#   '1700057G04Rik',
#   'Angpt1',
#   'Dnah5',
#   'Trpc4',
#   'Ccdc149',
#   'Abca8a',
#   'C1qtnf7',
#   'Abcc8',
#   'Dlgap2',
#   'Adgrl4',
#   'Cyp3a25',
#   'Hpse2',
#   'Snap91',
#   'Tpd52l1',
#   'Ugt8a',
#   'Bmx',
#   'Cacng4',
#   'Qsox1',
#   'Rbm24',
#   'Pla2r1',
#   'Kcnn3',
#   'Efcc1',
#   'Gm43507',
#   'Fam19a5',
#   'Kcnn2',
#   'Gm14964',
#   'Scn5a',
#   'Sis',
#   'Lmx1a',
#   'Rhbdl3',
#   'Creb3l1',
#   'Mcf2l',
#   'Col4a6',
#   'Add2',
#   'Gria2',
#   'Bmp6',
#   'Nebl',
#   'Fgf10',
#   'Chat',
#   'Gm10848',
#   'Galnt10',
#   'Nrg3os',
#   'Ablim3',
#   'Gm38505',
#   'Sgsm1',
#   'Slc35f1',
#   'Fam189a1',
#   'Tbx3os1',
#   'Rspo3',
#   'Gm13832',
#   'Pdia5',
#   '9030622O22Rik',
#   'D5Ertd615e',
#   'Agr2',
#   '4833422C13Rik',
#   'Slc8a3',
#   'Pkhd1l1',
#   'Sh2d6',
#   'Gm11149',
#   'Myt1',
#   'Ano7',
#   'Antxrl',
#   'Stk32a',
#   'Nfasc',
#   'Rfx6',
#   'Trpc3',
#   'Gm13269',
#   'Col11a1',
#   'Stxbp5l',
#   'Arfgef3',
#   'Slc38a11',
#   '4930578G10Rik',
#   'Slc12a8',
#   'Ern2',
#   'RP24-274B19.1',
#   'Gfra1',
#   'Spdef',
#   'Faxc',
#   'Sybu',
#   'Tmem108',
#   'Fut8',
#   'Lrrtm3',
#   'Sidt1',
#   '5330417C22Rik',
#   'Kcnma1'],
#  'Mesothelial': ['S100a6',
#   'Lama3',
#   'Phlpp2',
#   'Krt19',
#   'Gpx1',
#   'Fth1',
#   'Spag6l',
#   'Rpl9-ps6',
#   'Matk',
#   'March4',
#   'Srpx2',
#   'Mrc1',
#   'Pdk4',
#   'Alpi',
#   'Resp18',
#   'Snhg11',
#   'Abca13',
#   'Dnah9',
#   'Adgre1',
#   'Smim5',
#   'Krt23',
#   'Rinl',
#   'Gm15398',
#   'Jam2',
#   'Adcy2',
#   'Fcer2a',
#   'Dscaml1',
#   'Btk',
#   'Kcnj3',
#   'Tm6sf1',
#   'Ace2',
#   'Art3',
#   'Cidec',
#   'Aoah',
#   'Gcg',
#   'Rasip1',
#   'Kcnc2',
#   '5330434G04Rik',
#   'Cyp2c69',
#   'Gm42426',
#   'Wif1',
#   'Adm',
#   'Crmp1',
#   'Ina',
#   'Scube1',
#   'Chsy3',
#   'Entpd3',
#   'Kif1a',
#   'Ms4a6c',
#   'Ppp3ca',
#   'Scn7a',
#   'Gdap1',
#   'Hist1h2bj',
#   'Ppp1r14c',
#   'Prkcq',
#   'Rit2',
#   'Spock1',
#   'Stap1',
#   'Chat',
#   'Gm16233',
#   'Tnr',
#   'Agt',
#   'Gm43603',
#   'Shc4',
#   'Slc5a7',
#   'Efcc1',
#   'Klhl4',
#   'Amn',
#   'Dlgap2',
#   'Cd79b',
#   'Acaa1b',
#   'Trpv6',
#   'Pla2g7',
#   'Dach2',
#   'Zeb2',
#   'Arhgef15',
#   'Pkib',
#   'Muc1',
#   'Scg2',
#   'Gm9994',
#   'Cd79a',
#   'Tmprss5',
#   'Dmtn',
#   'Tbxas1',
#   'Ushbp1',
#   'Nek10',
#   'Srcin1',
#   'Cyth4',
#   'Stat4',
#   'Chrna3',
#   'Megf10',
#   'L3mbtl4',
#   'Itgal',
#   'Ppfia2',
#   'Pyy',
#   'Myt1l',
#   'Cd300lg',
#   'Gm12709',
#   'Fstl5',
#   'Flt1',
#   'Trpc3',
#   'Gimap3',
#   '2010106E10Rik',
#   'Cyp3a25',
#   'Rapgef5',
#   'Zfp9',
#   'Scn5a',
#   'Cxcr5',
#   'Rab3b',
#   'Tcp11',
#   'Nrros',
#   'Fgd5',
#   'Tbx3os1',
#   'Camk2a',
#   'Hs3st2',
#   'Igsf21',
#   'Gm43388',
#   'Cdh5',
#   'Bves',
#   'Gfra1',
#   'Fgf7',
#   'Gm4262',
#   'Plvap',
#   'BB365896',
#   'Kynu',
#   'Ms4a7',
#   'Tanc2',
#   'Ralyl',
#   'C130071C03Rik',
#   'Wdfy4',
#   'Ccm2l',
#   'Edil3',
#   'Cd37',
#   'Tpcn2',
#   'Pcsk2',
#   '1700057G04Rik',
#   'Reg4',
#   'Gimap4',
#   'Tespa1',
#   'Lcp2',
#   'Add2',
#   'Chst3',
#   'Lck',
#   'Gdpd2',
#   'Raet1e',
#   'Sval3',
#   'Kcnh7',
#   'Scn9a',
#   'Rnf150',
#   'Eng',
#   'A430078G23Rik',
#   'Dnah5',
#   'Kcnk3',
#   'Itga8',
#   'Nkx2-2os',
#   'Sh2d6',
#   'Ndst4',
#   'Zfp831',
#   'St8sia5',
#   'Myo1f',
#   'Ipcef1',
#   'Ngf',
#   'Cd40',
#   '1810006J02Rik',
#   '2310079G19Rik',
#   'Lypd6b',
#   'Dscam',
#   'Unc80',
#   'Ms4a6b',
#   'Slc7a14',
#   'Nckap1l',
#   'Trp53inp1',
#   'Cacna1h',
#   'Gm15987',
#   'Rhoh',
#   'Ly86',
#   'Spi1',
#   '1700041M19Rik',
#   'Scn3a',
#   'Zfp366',
#   'Tph1',
#   'Cd84',
#   'Cyyr1',
#   'Snap91',
#   'Tie1',
#   'Igsf11',
#   'Slc29a4',
#   'Lepr',
#   'Dtx1',
#   'Gm10863',
#   'Elavl3',
#   'Clnk',
#   'Arap3',
#   '4631405K08Rik',
#   'Mettl21b',
#   'Vwf',
#   '4930578C19Rik',
#   'Robo4',
#   'Kcnj6',
#   'Stab1',
#   'Apba2',
#   'Cxxc4',
#   'Pou2f2',
#   'Cd22',
#   'Cd53',
#   'Mtf2',
#   'Itk',
#   'Arg2',
#   'Cldn5',
#   'Bmx',
#   'Ces2b',
#   'Cyp2d9',
#   'Ggt1',
#   '4930552P12Rik',
#   'Runx3',
#   'Dync1i1',
#   'Myt1',
#   'Vipr2',
#   'Gm14342',
#   'Clvs1',
#   'Stxbp5l',
#   'Ecscr',
#   'Fam169b',
#   'Pik3cg',
#   'Gfra3',
#   'Cd48',
#   'Slfn2',
#   'Ugt8a',
#   '1810046K07Rik',
#   'Ms4a1',
#   'Kcnk13',
#   'Ly6g6d',
#   'Tmem252',
#   'Olfr78',
#   'Selplg',
#   'D5Ertd615e',
#   'Btla',
#   'Ttr',
#   'Gm15716',
#   'Alox5',
#   'Pik3r5',
#   'Mapk8ip2',
#   'Shf',
#   'Hck',
#   'Fam19a1',
#   'Klhl6',
#   'Adgrg3',
#   'Gm1965',
#   'Lrrc26',
#   'Pax5',
#   'Vps13b',
#   'Strip2',
#   'Gm38505',
#   'Ptpn22',
#   'Fam105a',
#   'Bank1',
#   'Slc6a17',
#   'Arhgap30',
#   'Rasd2',
#   'Tpd52l1',
#   'Gm6086',
#   'Btnl1',
#   'Vwa5b2',
#   'Ccdc129',
#   'Blk',
#   'A830019P07Rik',
#   'Rab27b',
#   'Adamts17',
#   'Gal3st2',
#   'Gm14344',
#   'Gm15998',
#   'Rhbdl3',
#   'Vav1',
#   'Rgs13',
#   'Plet1',
#   'Rrbp1',
#   'Ptprt',
#   'Kcnn2',
#   '4930419G24Rik',
#   'Acot4',
#   'Gm20642',
#   'Slfn3',
#   'S1pr1',
#   'Stk32a',
#   'Gm11963',
#   'Kcnh6',
#   'Adgrl4',
#   'Atcayos',
#   'Cd300lf',
#   'Sis',
#   'Lmx1a',
#   'P2rx1',
#   'Etnppl',
#   'Nrg3os',
#   'Slamf6',
#   'Best2',
#   'Plet1os',
#   'Mctp1',
#   'Rfx6',
#   'Gimap8',
#   'Anxa13',
#   'Skap1',
#   'Sytl5',
#   'Piwil4',
#   'A4gnt',
#   'Qsox1',
#   'St3gal6',
#   'Ramp1',
#   'Spink4',
#   'Sval1',
#   'Mir142hg',
#   'Myct1',
#   'St18',
#   'Gpr20',
#   'Tnfaip8',
#   'Cbfa2t3',
#   'Scnn1g',
#   'Gm43634',
#   'Sorcs2',
#   'Nkx2-2',
#   'Slc18a1',
#   'Atoh1',
#   'Creb3l1',
#   'Insrr',
#   'Pde2a',
#   'Ikzf3',
#   'Klf12',
#   'D930020B18Rik',
#   'Plcb4',
#   'Pdia5',
#   'Gm13832',
#   'Etv5',
#   'Pacsin1',
#   'Sybu',
#   'Kit',
#   'Fam189a1',
#   'Spdef',
#   'Hepacam2',
#   'Slc12a8',
#   'Ano7',
#   '9030622O22Rik',
#   'Kcnma1'],
#  'Myocye': ['Prdx6',
#   'Atp2b1',
#   'Aldh2',
#   'Tgm3',
#   'Kif5a',
#   'Sult4a1',
#   'Tll1',
#   'Pdgfra',
#   'Acaa1b',
#   'Gm6086',
#   'B530045E10Rik',
#   'Tpcn2',
#   'Frmd3',
#   'Zfp9',
#   'Rhbdl3',
#   'Adamts3',
#   'Gdpd2',
#   'Zcchc12',
#   'Clstn2',
#   'Gm20186',
#   'Tspan6',
#   'Erg',
#   'Pyy',
#   'Eef1a2',
#   'Cnr1',
#   'Muc1',
#   '2010106E10Rik',
#   'Vwf',
#   'Nrxn2',
#   'Flt1',
#   'Nlrc5',
#   'Ggt1',
#   'Zcchc18',
#   'Dtx1',
#   'Ngfr',
#   'Gm20400',
#   'Atp6v0a4',
#   'Defb37',
#   'Abca9',
#   'Cadm3',
#   'Gm9994',
#   'Cyp3a25',
#   'Adamts17',
#   'Cyp2c69',
#   'Ces2b',
#   'Dnajc6',
#   'Gcg',
#   'Chd5',
#   'Spib',
#   'Synpr',
#   'Cd247',
#   'St3gal1',
#   'Camk2a',
#   'Insm1',
#   'Grid1',
#   'Snca',
#   'Mapk8ip2',
#   'Ina',
#   'C3',
#   'Gxylt2',
#   'Sval3',
#   'Gdap1',
#   'Etnppl',
#   'Gng4',
#   'Galnt15',
#   'Faim2',
#   'Tmem151a',
#   'Btk',
#   'Cyp2d9',
#   'Fcer2a',
#   'Gjb5',
#   'Ccdc85a',
#   'Cybb',
#   'P2rx1',
#   'Chst3',
#   'Slfn2',
#   'Unc13c',
#   'Resp18',
#   'Muc16',
#   'Spock1',
#   'Arhgap22',
#   'Rinl',
#   'Nfasc',
#   'Selplg',
#   'Slfn5',
#   'Rsad2',
#   'P2rx2',
#   'Wif1',
#   'Ace2',
#   'Pik3cd',
#   'Syt4',
#   'Sla',
#   'Dmtn',
#   'Rasip1',
#   'Cyth4',
#   'Rgs22',
#   'Crmp1',
#   'Cfap44',
#   'Adgrg2',
#   'Nkx2-2os',
#   'Gm15398',
#   'Kcnq3',
#   'Sh2d7',
#   'Fam169b',
#   'Slc5a7',
#   'Tmem179',
#   'Adam11',
#   'Gm37459',
#   'Trpv6',
#   'Ms4a7',
#   'Aoah',
#   'Vill',
#   'Mrc1',
#   'Krt23',
#   '1810046K07Rik',
#   'Scn11a',
#   'Cd300lg',
#   'Atp2b2',
#   'Sox10',
#   'Pla2g7',
#   'Gfra3',
#   'Alox5',
#   'Pax6os1',
#   'Cr2',
#   'Rasgrp1',
#   'Lgi4',
#   'Slc29a4',
#   'Zfp831',
#   'Chrna3',
#   'Txk',
#   'C130071C03Rik',
#   'Ms4a6c',
#   'Pik3r5',
#   'Tspan32',
#   'Slc35d3',
#   'Baiap3',
#   'Tmprss5',
#   'Ccm2l',
#   'Trpm5',
#   'Fam163a',
#   'Kynu',
#   'Arhgef15',
#   'Ly6g6d',
#   'Add2',
#   'Cacng4',
#   'Galr1',
#   'Igsf21',
#   'Kcnj6',
#   'Nckap1l',
#   'Tph1',
#   'Cd244',
#   'Cd48',
#   'Klhl6',
#   'Upk1b',
#   'Cd53',
#   'Blk',
#   'Gm15987',
#   'Lck',
#   'Lrfn5',
#   'Soga3',
#   'Thsd1',
#   'Efcc1',
#   'Ciita',
#   'Entpd3',
#   'Ms4a6b',
#   'Clnk',
#   'Ms4a1',
#   'Tespa1',
#   'Gm43388',
#   'Cldn5',
#   'Ebf3',
#   'Clvs1',
#   'March4',
#   'Snap91',
#   'Acap1',
#   'Raet1e',
#   'Cd300lf',
#   'Stap1',
#   'Gimap4',
#   'Cxxc4',
#   'Abcg3',
#   'Gimap3',
#   'Scn5a',
#   'Shc4',
#   'Cyp4x1',
#   'Elavl2',
#   '4930555F03Rik',
#   'Rgs8',
#   'Lbp',
#   'Slamf6',
#   'Scn9a',
#   'Mmd2',
#   'Lcp2',
#   'Ralyl',
#   'Itk',
#   '4930419G24Rik',
#   'Cerkl',
#   'Hs3st2',
#   'Cd84',
#   'Kcna6',
#   'Tnr',
#   'Gm20594',
#   'Jakmip2',
#   'Ushbp1',
#   'Ndst4',
#   'Ipcef1',
#   'Ly86',
#   'Srcin1',
#   'Wdfy4',
#   'Gm15716',
#   'Gm43603',
#   '1810006J02Rik',
#   'Slc26a4',
#   'Ptpn22',
#   'Kcnc2',
#   'Arhgap30',
#   'Myt1l',
#   'Cd226',
#   'Cd22',
#   'Gria2',
#   'Sh2d6',
#   'Emb',
#   'Klrd1',
#   'Dscaml1',
#   'Runx3',
#   'Ccdc129',
#   'Miat',
#   'Nxph1',
#   'Col11a1',
#   'Gm10863',
#   'Hck',
#   '4930578C19Rik',
#   'Myt1',
#   'Gm11417',
#   'Slfn3',
#   '9530059O14Rik',
#   'Btla',
#   'Rhoh',
#   'Chat',
#   'Rgs13',
#   'Pax5',
#   'Lmx1a',
#   'Gm38505',
#   'Bmx',
#   'Gm20642',
#   'Gnat3',
#   'Rfx6',
#   'Nrg3os'],
#  'Neuron_1': ['Pde3a',
#   'Tmsb4x',
#   'Itm2b',
#   'Atp2b1',
#   'March3',
#   'Ms4a1',
#   'Ugt8a',
#   'Lck',
#   'Lama2',
#   'Cd247',
#   'Alox5',
#   'Kcnmb2',
#   'Gm44040',
#   'Fgf10',
#   'C4b',
#   'Vill',
#   'Abcg3',
#   'Slc10a6',
#   'Cd180',
#   'Upk3b',
#   'Fgf7',
#   'Cdkn1c',
#   'Csf1r',
#   'Angptl4',
#   '4930467D21Rik',
#   'Gbp5',
#   'Fam169b',
#   'Rfx6',
# ...
#   'Gm13203',
#   'Btla',
#   'Ces2b',
#   'Adm',
#   'Cd22',
#   'Wnt8b',
#   'Gm4262',
#   'Gm43388',
#   'Abca13',
#   'Slc38a11',
#   'Blk',
#   '1700041M19Rik',
#   'Cr2',
#   'Myzap',
#   'Trpv6',
#   'Gm43603',
#   'Pax5',
#   'Gp6',
#   'Gm43391',
#   'Gm16233',
#   'St8sia5'],
#  'T_cell': ['Car1',
#   'Actb',
#   'Lamb3',
#   '1810065E05Rik',
#   'Fth1',
#   'Itm2b',
#   'Cfl1',
#   'Aldh1a1',
#   'Plvap',
#   'Bcam',
#   'Agt',
#   'Btnl1',
#   'Acot4',
#   'Ska3',
#   '1700041M19Rik',
#   'Aebp1',
#   'Pou2f3',
#   'Krt23',
#   'Ces2b',
#   'Gm15987',
#   'Gabre',
#   'Adm',
#   'Ugt8a',
#   'Kynu',
#   'Crispld1',
#   'Gng4',
#   'Samd5',
#   'Adgre1',
#   'Sval3',
#   '4930452B06Rik',
#   'Fam221a',
#   'Cdc25c',
#   'C4b',
#   'Etnppl',
#   'Kcnh6',
#   'Spib',
#   'Spon2',
#   'Soga3',
#   'Gm1123',
#   'Grik4',
#   'Smim5',
#   'Zfp9',
#   'Ms4a4d',
#   'Htra3',
#   'Adgrg3',
#   'Lrrc26',
#   'Igsf10',
#   'Kif18b',
#   'P4hb',
#   'Plat',
#   'Chrna3',
#   'Gas1',
#   'Slc5a7',
#   'AI838599',
#   'Atp2a3',
#   'Insm1',
#   'Grhl3',
#   'P2rx2',
#   'Scgn',
#   'Gria2',
#   'Hs3st4',
#   'Faim2',
#   'Kcnk3',
#   'Gm15998',
#   'Ciita',
#   'Elavl3',
#   '4631405K08Rik',
#   'Qsox1',
#   'Ankle1',
#   'Adgrg2',
#   '2310079G19Rik',
#   'Tspan6',
#   'Atp2b2',
#   'L3mbtl4',
#   'Pkib',
#   '5330434G04Rik',
#   'Camk2a',
#   'Cyp2j9',
#   'Cnr1',
#   'Megf10',
#   'Tmprss5',
#   'Rps6ka2',
#   'Grin1',
#   '4833422C13Rik',
#   'Igf2bp1',
#   'Ina',
#   'Rarres2',
#   'BB365896',
#   'Rhbdl3',
#   'Nuak1',
#   'Vill',
#   '9430020K01Rik',
#   'Klhl4',
#   'Myt1l',
#   'Add2',
#   'Kcnc2',
#   'Tnr',
#   'Snca',
#   'C130071C03Rik',
#   'Erg',
#   'Tph1',
#   'B530045E10Rik',
#   'Car8',
#   'Ltbp3',
#   'Avil',
#   'Armc2',
#   'Khdrbs2',
#   'Rasip1',
#   'Cspg4',
#   'Dnah9',
#   'Nalcn',
#   'Cacna1h',
#   'Abcc8',
#   'Gabra3',
#   'Aoc3',
#   'Kcnj6',
#   'Adrbk2',
#   'Gm13832',
#   'Tpsg1',
#   'Lrrc17',
#   'Cyp2f2',
#   'Hap1',
#   'Chd5',
#   'Syt1',
#   'Ecscr',
#   'Gm16233',
#   'Zcchc12',
#   'Abca9',
#   'Cd34',
#   'Cfap44',
#   'Mest',
#   'Mgat5',
#   'Cbfa2t3',
#   'Gm42426',
#   'Kcnd2',
#   'Cntnap2',
#   'Kif1a',
#   'Gm17276',
#   'Btk',
#   'Wnt5a',
#   'Gfra3',
#   'Ly6g6d',
#   'Medag',
#   'Agr2',
#   'Tead4',
#   'Fstl5',
#   'Slc12a8',
#   'Cd180',
#   'Galnt10',
#   'Cdh3',
#   'Sytl5',
#   'Rasd2',
#   'Hmgn3',
#   'Spock1',
#   'Wif1',
#   'Slc29a4',
#   'Csgalnact1',
#   'Chst3',
#   'Trpv6',
#   'Fcer2a',
#   'Gcnt3',
#   '9530036O11Rik',
#   'Dmtn',
#   'Cxxc4',
#   'Rit2',
#   'Srcin1',
#   'Tbxas1',
#   'Adamts2',
#   'Pcsk2',
#   'Ccdc80',
#   'Cplx2',
#   'Gm16183',
#   'Ntng1',
#   'Arhgef15',
#   'Muc1',
#   'Esam',
#   'Dixdc1',
#   'Rgs22',
#   'Rab7b',
#   'Gal3st2',
#   'Map6',
#   'Fam163a',
#   'Nrxn2',
#   'Gm6086',
#   'Nek10',
#   'Tmem151a',
#   'Synpr',
#   'Appl2',
#   'Pstpip2',
#   'Myrip',
#   'Tpd52l1',
#   'Csf1',
#   'Nfatc4',
#   'Strip2',
#   'Kcna6',
#   'Ndst4',
#   'Olfr78',
#   'Phactr3',
#   'Hck',
#   'Lrch2',
#   'Ppp1r14c',
#   'Cyp2d9',
#   'Sorcs2',
#   'Cldn5',
#   'Tie1',
#   'Ablim3',
#   'Gxylt2',
#   'Gjb5',
#   'Slc7a14',
#   'Bace2',
#   'Ptprt',
#   'Ccm2l',
#   'Musk',
#   'Syt13',
#   'Trpc4',
#   'Unc80',
#   'Pappa2',
#   'Clstn2',
#   'Ly86',
#   'Gm43603',
#   'Gpr20',
#   'Fstl4',
#   'Cux2',
#   'Fbln1',
#   'Igsf21',
#   'Ppfia2',
#   'Sybu',
#   'Fbln5',
#   'Ebf3',
#   'Pi16',
#   'Adam11',
#   'Evc2',
#   'Mrc1',
#   'Arhgap22',
#   'Bmp6',
#   'Shc4',
#   '1700111E14Rik',
#   'Pax5',
#   'Otud7a',
#   'Rasa4',
#   'Snhg11',
#   'Gm12709',
#   'Fgf7',
#   'Plcb4',
#   'Tgfbr3',
#   'Srpx2',
#   'Rab3b',
#   'Thsd1',
#   'Eng',
#   'Rapgef3',
#   'Gm9994',
#   'Best2',
#   '9530059O14Rik',
#   'Tnfrsf11b',
#   'Igf1',
#   'Ttr',
#   'Igsf11',
#   'Chat',
#   'Clip4',
#   'Col24a1',
#   'Gm15398',
#   'Cdh5',
#   'Ddo',
#   'Vwf',
#   'Ano7',
#   'Rgs13',
#   'Mctp1',
#   'Shisa6',
#   'Ccdc149',
#   'Ushbp1',
#   'A630023A22Rik',
#   'Dlg2',
#   'Clvs1',
#   'Syt7',
#   'Capn8',
#   'Speg',
#   'Kcnj3',
#   'Slc8a3',
#   'Scube2',
#   'C1galt1',
#   'Dnm3os',
#   'Dlgap2',
#   'Scn2a1',
#   'Srrm4',
#   'Gcc2',
#   'Foxa3',
#   'Cacnb4',
#   'Rep15',
#   'Dync1i1',
#   'Alox5',
#   'Tmem108',
#   'Kcnq4',
#   'Fam198b',
#   'Chrdl1',
#   'Cadm3',
#   'Tmc5',
#   'Sgsm1',
#   'Art3',
#   'Pdia5',
#   'Gpc3',
#   'Cacng4',
#   'Tacr1',
#   'Kcnmb2',
#   'Pla2g7',
#   'Aldh1a3',
#   'Cemip',
#   'Gabrb3',
#   'Lgi4',
#   'Hsd11b2',
#   'Scnn1g',
#   'Snap91',
#   'Gm20642',
#   'Angpt1',
#   'Kcnn2',
#   'Sox10',
#   'Astn1',
#   'Syt14',
#   'Slc6a17',
#   'Agtr1a',
#   'Slc18a1',
#   'Tsc22d1',
#   'Tnfaip8l3',
#   'RP24-274B19.1',
#   'Jakmip2',
#   'Pald1',
#   'March4',
#   'Ralyl',
#   'Grid1',
#   'Nxph1',
#   'Ntm',
#   'Fam189a1',
#   'Scube1',
#   'Isl1',
#   'Vwa5b2',
#   'Jph1',
#   'Sh2d6',
#   'Hepacam2',
#   'Chsy3',
#   '4930467D21Rik',
#   'Ildr2',
#   'Dnah5',
#   'Ccdc129',
#   'Lrfn5',
#   'Rnf150',
#   'Pax6os1',
#   'Flt1',
#   'Pdgfra',
#   'Stab1',
#   '4930552P12Rik',
#   'Mfap5',
#   'Xkr4',
#   'Arsj',
#   'Galnt16',
#   'Enpp2',
#   'Gm14964',
#   'Kcnh7',
#   'Kdr',
#   'Sval1',
#   '9030622O22Rik',
#   'Rassf6',
#   'P2rx4',
#   'Ptgis',
#   'Arfgef3',
#   'Scn7a',
#   'Galnt15',
#   'Tbx3os1',
#   'Ngf',
#   'Hpse2',
#   'Cfh',
#   'Ntf3',
#   'Myt1',
#   'Fam184a',
#   'Apba2',
#   'Ern2',
#   'Efemp1',
#   'Galnt7',
#   'Rasgrp3',
#   'Ednra',
#   'St3gal6',
#   'Rgs17',
#   'Slc10a6',
#   'Zdhhc14',
#   'Ptprn2',
#   'Fam19a5',
#   'Pkhd1l1',
#   'Slc4a7',
#   'Nfasc',
#   'Col4a6',
#   'Atp2c2',
#   'Tanc2',
#   'Fut8',
#   'Bves',
#   'Adgrl4',
#   'Bdkrb2',
#   'Lepr',
#   'Lmx1a',
#   'Creb3l1',
#   'Lbp',
#   'Itga8',
#   'Rrbp1',
#   'Abca8a',
#   'Chrm3',
#   'Pappa',
#   'Efcc1',
#   'Jam2',
#   'Gm11149',
#   'Nav2',
#   'Faxc',
#   'Plpp1',
#   'Kcns3',
#   'Rfx6',
#   'Klf12',
#   'Prdm6',
#   'Mcf2l',
#   '5330417C22Rik',
#   'Adamts19',
#   'Gfra1',
#   'D5Ertd615e',
#   '4930578C19Rik',
#   'Kcnma1',
#   'Rspo3',
#   'Fgf10',
#   'Zfp366',
#   'Bmx',
#   'Col11a1',
#   'Nrg3os',
#   'Trpc3',
#   'Adamtsl3',
#   'Pla2r1',
#   'Radil',
#   'Frem2',
#   'Slc12a2',
#   'Stk32a',
#   'St18',
#   'Dgki',
#   'Gpm6a',
#   'Slc35f1',
#   'Gm43507',
#   'Stxbp5l',
#   'Nova1',
#   '4930578G10Rik',
#   'C1qtnf7',
#   'Arhgap28',
#   'Plcb1',
#   'Kcnn3',
#   'Antxrl',
#   'Gm10848',
#   'Slc38a11',
#   'Ica1',
#   'Gm26889',
#   'Gm13269',
#   'Lrrtm3'],
#  'Tuft': ['Krt8',
#   'Kcnq1',
#   'Cldn7',
#   'Cyp4f14',
#   'Pparg',
#   'Tcf7l2',
#   'mt-Nd3',
#   'Tinag',
#   'Dnah8',
#   '4631405K08Rik',
#   'Ly6c1',
#   'Gm14344',
#   'Ace2',
#   'Gabra3',
#   'Gabre',
#   'Syt4',
#   'Defb37',
#   'Muc1',
#   'Mlph',
#   'Sval3',
#   'Cdc6',
#   'Omd',
#   'Resp18',
#   'Trpv6',
#   'Cyp3a25',
#   'Scg2',
#   'Txk',
#   'Scgn',
#   'Mettl21b',
#   'Gm42426',
#   'Pirt',
#   'Gxylt2',
#   'Ndrg4',
#   'Vill',
#   'Grhl3',
#   'Vwf',
#   'Plekhd1os',
#   'Kcnh7',
#   'P2rx4',
#   'Ntm',
#   'Chrna3',
#   'Clec3b',
#   'Mcf2l',
#   'Sult4a1',
#   'Sis',
#   'Fam212b',
#   'Aunip',
#   'Aldh1a3',
#   'Adgre1',
#   'Ano2',
#   'Plat',
#   'Pyy',
#   'Atp2b2',
#   'Cfap44',
#   'Nkx2-2os',
#   'Wnt5a',
#   'Kynu',
#   'Gm1965',
#   'Etv1',
#   'Tbx2',
#   'Gm12506',
#   'Cidec',
#   'Wnt8b',
#   'Faim2',
#   'Kcnn2',
#   'Trp53inp1',
#   'Ina',
#   'Hs3st4',
#   'Cyp2f2',
#   'Gja5',
#   'Slfn5',
#   'Pi16',
#   'Lrrc26',
#   'Slc22a4',
#   'Zcchc18',
#   'Muc16',
#   'Plet1',
#   'Crispld1',
#   'Scn9a',
#   'Gem',
#   'Anxa13',
#   'Abcb1b',
#   'Dhrs9',
#   '1700041M19Rik',
#   'Prph',
#   'Kif18b',
#   'Slc22a1',
#   'Sv2a',
#   'Rit2',
#   'Arhgef15',
#   'Smim3',
#   'Cd84',
#   'Dach1',
#   'Csf1r',
#   'Themis',
#   'Gjb5',
#   'Sla',
#   'Pax5',
#   'Tpsg1',
#   'Fam163a',
#   'Nalcn',
#   'Cd248',
#   'Bcam',
#   'F13a1',
#   'Chst3',
#   'Thsd1',
#   'Btnl1',
#   'Jam2',
#   '2310079G19Rik',
#   'H2-DMb1',
#   'Myo1f',
#   'Ms4a4d',
#   'Clstn2',
#   'Lrfn5',
#   'Pla2g7',
#   'C3',
#   'Scn11a',
#   'Pappa2',
#   'Lrrc4b',
#   'Tnfsf15',
#   'Dnah9',
#   'Ndst4',
#   'Ipcef1',
#   'Ces2b',
#   'Gbp5',
#   'Aoc3',
#   'Gria2',
#   'Cemip',
#   'Nrxn2',
#   'Man1c1',
#   'Ptgis',
#   'Gm13832',
#   'Hist1h2bj',
#   'Rasgrp1',
#   'Rgs1',
#   'Ttr',
#   'Pcsk2',
#   'Slpi',
#   'H2-Q7',
#   'Igf1',
#   'Smim5',
#   'Ugt8a',
#   'Abca13',
#   'Tcp11',
#   'Aoah',
#   'Medag',
#   'Ccdc149',
#   'Ddo',
#   'Stap1',
#   'Scn5a',
#   'B530045E10Rik',
#   'Apba2',
#   'Nxph1',
#   'S1pr3',
#   'Elavl3',
#   'Cmtm8',
#   'Miat',
#   'Zfp831',
#   'Cyth4',
#   'Cr2',
#   'Gm37459',
#   'Abcg3',
#   'Ms4a6b',
#   'Ms4a1',
#   'March4',
#   'Shc4',
#   'Tph1',
#   'Spink4',
#   'Nuak1',
#   'Nlrc5',
#   'Add2',
#   'Cyp2d9',
#   'Sytl5',
#   'Khdrbs2',
#   'Srcin1',
#   'Mapk8ip2',
#   'Chrdl1',
#   'Crmp1',
#   'C4b',
#   'Emb',
#   'Disc1',
#   'Speg',
#   'C130071C03Rik',
#   'Srrm4',
#   'Il1rl2',
#   'Musk',
#   'Megf10',
#   'Slfn3',
#   '4930552P12Rik',
#   'Slc5a7',
#   'Raet1e',
#   '2010106E10Rik',
#   'Ebf3',
#   'Ms4a7',
#   'Mfap5',
#   'L3mbtl4',
#   'Olfr78',
#   'Tacr1',
#   'Scube2',
#   'Clnk',
#   'Mest',
#   'Kif5a',
#   'Dnajc6',
#   'Ccdc85a',
#   'Erg',
#   'Gm44040',
#   'Nrros',
#   'Arhgap22',
#   'Gm14342',
#   'Cspg4',
#   'Cadm3',
#   'Cd93',
#   'Gm9994',
#   'Soga3',
#   'Etnppl',
#   'Gpc3',
#   'Slit1',
#   'Chrm3',
#   'Fstl5',
#   'Rarres2',
#   'Tespa1',
#   'Pkib',
#   'Ggt5',
#   'Pik3cd',
#   'Faxc',
#   'Gal3st2',
#   'Fbln5',
#   'Col24a1',
#   '4930419G24Rik',
#   'Gabbr2',
#   'Cxxc4',
#   'Ildr2',
#   'Rab3b',
#   'Pou2f2',
#   'Fbln1',
#   'Myt1l',
#   'Tmprss5',
#   'Igsf21',
#   'She',
#   'Gm12709',
#   'Cybb',
#   'Ralyl',
#   'Gm10863',
#   'Scel',
#   'Zfp366',
#   'Btk',
#   'Gng4',
#   'Slfn2',
#   'Kcnq3',
#   'Ciita',
#   'Htra3',
#   'Gm16233',
#   'Kcnh6',
#   'Slc18a1',
#   'Kcnj3',
#   'Scn2a1',
#   'Cyp2j9',
#   'Snap91',
#   'Kcnd2',
#   'Trpc4',
#   'Col6a4',
#   'Galnt15',
#   'Nckap1l',
#   'St6galnac5',
#   '9530059O14Rik',
#   'Kcnc2',
#   'Eepd1',
#   'Cd34',
#   'Qsox1',
#   'Kcns3',
#   'Fcer2a',
#   'Cd53',
#   'Igfbp6',
#   'Efemp1',
#   'Agtr1a',
#   'Galnt7',
#   'Iigp1',
#   'Apc2',
#   '9430020K01Rik',
#   'Tm6sf1',
#   'Rab7b',
#   'Lax1',
#   'Cdh3',
#   'Gm15398',
#   'Gpm6a',
#   'Slc7a14',
#   'Slc12a2',
#   'Kcnj6',
#   'Ackr2',
#   'Piwil4',
#   'Galnt10',
#   'Cerkl',
#   'Gimap4',
#   'Ltbp3',
#   'Grid1',
#   'Selplg',
#   'Dtx1',
#   'Gas1',
#   'Cd244',
#   'Dnm3os',
#   'Tbxas1',
#   'Igsf10',
#   'Slc10a6',
#   'Insrr',
#   'Tsc22d1',
#   'AI607873',
#   'A4gnt',
#   'Ntng1',
#   'Rbm24',
#   'Prdm6',
#   'Syt14',
#   'Kcnk13',
#   'Gm14964',
#   'Slc8a3',
#   'Hs3st2',
#   'Adgrg3',
#   'Mrc1',
#   'Ar',
#   'Stab1',
#   'Klhl6',
#   'Gm38505',
#   'D930020B18Rik',
#   'Gm13052',
#   'Cldn5',
#   'Cacng4',
#   'Slc6a15',
#   'Gpr20',
#   'Tpcn2',
#   'Grik4',
#   'A630023A22Rik',
#   'Plet1os',
#   'Tmem179',
#   'Fam169b',
#   'Runx3',
#   'Reg4',
#   'Fam184a',
#   'Adam11',
#   'Lrrn2',
#   'Atoh1',
#   'Eya4',
#   'Tmc5',
#   'Zfp9',
#   '4930578C19Rik',
#   'Ahrr',
#   'Baiap3',
#   'Edil3',
#   'Btnl9',
#   'Arsj',
#   'Lbp',
#   'Syt13',
#   'Nrg3os',
#   'Tnr',
#   '4930555F03Rik',
#   'Cd48',
#   'Gabrb3',
#   '4930467D21Rik',
#   'Gm1123',
#   'Actn2',
#   'Lgi4',
#   'Ntf3',
#   'Flt1',
#   'Tnfaip8l3',
#   'Sh3gl3',
#   'Skap1',
#   'Aebp1',
#   'Foxa3',
#   'Galnt16',
#   'Itk',
#   'Snhg11',
#   'Spock1',
#   'Gm20642',
#   'Etv5',
#   'Slc6a17',
#   'Tpd52l1',
#   'Nkx2-2',
#   'Hmgn3',
#   'Csf1',
#   'Gm43603',
#   'A830019P07Rik',
#   'Ptprt',
#   'Dlgap2',
#   'Btla',
#   'Best2',
#   'Adamtsl3',
#   'Cntn1',
#   'Rhoh',
#   'Scube1',
#   'Galr1',
#   'Arhgap28',
#   'Stxbp5l',
#   'Ly86',
#   'Hsd11b2',
#   '5330434G04Rik',
#   'RP24-274B19.1',
#   'Radil',
#   'Bmp6',
#   'Fam19a5',
#   'Gm43634',
#   'Gm17276',
#   '5033428I22Rik',
#   'Lmx1a',
#   'Ednra',
#   'Tie1',
#   'Lcp2',
#   'Cd226',
#   'Clip4',
#   'Rapgef3',
#   'Gfpt2',
#   'Nfatc4',
#   'Slc35f1',
#   'Ngf',
#   'Vwa5b2',
#   'Cbfa2t3',
#   'Gm6086',
#   'Ccdc80',
#   'Adgrl4',
#   'Nipal2',
#   'Itga8',
#   'Gfra1',
#   'Fgf7',
#   'Pappa',
#   'Bves',
#   'Adamts19',
#   'Ms4a6c',
#   'Sgsm1',
#   'Angpt1',
#   'Fam198b',
#   'Meox2',
#   'Kcnmb2',
#   'Ushbp1',
#   'Wdfy4',
#   'Phactr3',
#   'Sox5os4',
#   'Bdkrb2',
#   'Pdgfra',
#   'Col4a6',
#   'Myct1',
#   'Cdh5',
#   'Frem2',
#   'Ptpn22',
#   'Tbx3os1',
#   'Lepr',
#   'Myt1',
#   'Evc2',
#   'Armc2',
#   'Efcc1',
#   'Spdef',
#   'Hpse2',
#   'St6gal1',
#   'Fgf10',
#   'Rhbdl3',
#   'Dmtn',
#   'Gcc2',
#   'Kdr',
#   'Prkcq',
#   'Pdia5',
#   'Ramp1',
#   'Jph1',
#   'Pacsin1',
#   'Abca9',
#   'Col11a1',
#   'Plcb4',
#   'Arhgap30',
#   'S1pr1',
#   'Art3',
#   'Kcnn3',
#   'Lrch2',
#   'Abca8a',
#   'Adamts17',
#   'Gm43507',
#   'Gm43388',
#   'Map6',
#   'Pkhd1l1',
#   'Creb3l1',
#   'Rfx6',
#   'Enpp2',
#   'Kcna6',
#   'Ern2',
#   'Agr2',
#   '4833422C13Rik',
#   'Sidt1',
#   'Trpc3',
#   'C1galt1',
#   'Arfgef3',
#   'Gm11149',
#   'Nova1',
#   'Astn1',
#   'Chsy3',
#   'D5Ertd615e',
#   'Slc38a11',
#   'Mir142hg',
#   'Scn7a',
#   'Atp2c2',
#   'Ikzf1',
#   'C1qtnf7',
#   'Cfh',
#   'Arap3',
#   '4930578G10Rik',
#   '5330417C22Rik',
#   'Isl1',
#   'Scnn1g',
#   'Stk32a',
#   'Rasgrp3',
#   'Sybu',
#   'Ikzf3',
#   'Slc12a8',
#   '9030622O22Rik',
#   'Gm10848',
#   'Kcnma1',
#   'Rspo3',
#   'A430078G23Rik',
#   'Gm13269'],
#  'Vascular': ['Calm1',
#   'Actb',
#   'Prdx6',
#   'Actg1',
#   'Zg16',
#   'Emp1',
#   'Plec',
#   'Fth1',
#   'Upp1',
#   'Shf',
#   'Eef1a2',
#   'Sybu',
#   'Grin1',
#   'Cyp2c69',
#   'Sval1',
#   'Syt4',
#   'Wnt5a',
#   'Ly6g6d',
#   'Agt',
#   'Il17rb',
#   'Mettl21b',
#   'Acaa1b',
#   'Cxxc4',
#   'Chd5',
#   'Piezo2',
#   'Acot4',
#   'Vill',
#   'Nrxn2',
#   'Cyp2f2',
#   'Medag',
#   'Hap1',
#   'Ggt1',
#   'Clec3b',
#   'Prph',
#   'Sla',
#   'Cfh',
#   'Muc1',
#   'Best2',
#   'Cdh8',
#   'Ttr',
#   'Spon2',
#   'Atp6v0a4',
#   'Htra3',
#   'Grik4',
#   'Csf1r',
#   'Etnppl',
#   'Abca13',
#   'Resp18',
#   'Gm17276',
#   'Pla2r1',
#   'Ngfr',
#   'Ggt5',
#   'Kcnj3',
#   'Spink4',
#   'Rarres2',
#   'Pik3cg',
#   'Rab3b',
#   'Fam163a',
#   'Etv1',
#   'Shc4',
#   'Txk',
#   'St6galnac5',
#   'Fbln1',
#   'Rit2',
#   'Btnl1',
#   'Slc29a4',
#   'Atp2a3',
#   'Cidec',
#   'Cybb',
#   'Gm1965',
#   '4631405K08Rik',
#   'Gas1',
#   'Entpd3',
#   '1700041M19Rik',
#   'Kcnh6',
#   'Ms4a1',
#   'Rasgrp1',
#   'Myo1f',
#   'Slc35f1',
#   'Gal3st2',
#   'Krt23',
#   'Cemip',
#   'Kcnmb2',
#   'Matk',
#   '2310079G19Rik',
#   'L3mbtl4',
#   'Tsc22d1',
#   'Srpx2',
#   'Btk',
#   'Kcnk3',
#   'Snca',
#   'Clstn2',
#   'Pdia5',
#   'Igsf10',
#   'Kif5a',
#   'Rgs1',
#   'Pappa2',
#   '4930419G24Rik',
#   'Syt1',
#   'Sis',
#   'Gm12381',
#   'Unc13c',
#   'Cd53',
#   'Sv2a',
#   'Camk2a',
#   'Cacnb4',
#   'Ddo',
#   'Lck',
#   'Efcc1',
#   'Gm9994',
#   'Cyp3a25',
#   'Fcer2a',
#   'Ccdc149',
#   'Kcna6',
#   'Fam221a',
#   'Pirt',
#   'Hsd11b2',
#   'Ppfia2',
#   'Adgre1',
#   'Armc2',
#   'Frmd3',
#   'Gjb5',
#   'Scgn',
#   'Fgf7',
#   'Kcns3',
#   'Ace2',
#   'Tacr1',
#   'Ugt8a',
#   'Ndst4',
#   'Cux2',
#   'Qsox1',
#   'Itga11',
#   'Cntn1',
#   'Pkib',
#   'Gm16183',
#   'Zfp831',
#   'Jakmip2',
#   'Synpr',
#   'Slc7a14',
#   'Rgs22',
#   'Hs3st4',
#   'Tespa1',
#   'Gm42426',
#   'Dtx1',
#   'Snap91',
#   'Trpv6',
#   'Gdpd2',
#   'Tpcn2',
#   'Crmp1',
#   'Raet1e',
#   'Gm37459',
#   'Gm16233',
#   'Clvs1',
#   'Cspg4',
#   '4930552P12Rik',
#   'Gm14342',
#   '5330434G04Rik',
#   'Gng4',
#   'P2rx1',
#   'Rab7b',
#   'Hs3st2',
#   'Bace2',
#   'Adamtsl3',
#   'Mrc1',
#   'Gimap3',
#   'Cfap44',
#   'Anxa13',
#   'Agtr1a',
#   'Nova1',
#   'Ms4a4d',
#   'Efemp1',
#   'Srrm4',
#   'Baiap3',
#   'Elavl3',
#   'Cyp2d9',
#   'Sh3gl3',
#   'Chrna3',
#   'Clip4',
#   'Gm10863',
#   'Zfp9',
#   'Tnfaip8l3',
#   'Muc2',
#   'Arg2',
#   'Scnn1g',
#   'Vav1',
#   'Cacng4',
#   'Pik3r5',
#   'Kcnq3',
#   '4930467D21Rik',
#   'Pdgfra',
#   'Abca9',
#   'Wif1',
#   'Soga3',
#   'Gpr20',
#   'Megf10',
#   'Gm43634',
#   'Eya4',
#   'Olfr78',
#   'Gpc3',
#   'Alox5',
#   'Emb',
#   'Kcnh7',
#   'Ralyl',
#   'Chrm3',
#   'Pygl',
#   'Ciita',
#   'Aoah',
#   'Kcnd2',
#   'Otud7a',
#   'Tmprss5',
#   'Pax6os1',
#   'Selplg',
#   'Fstl5',
#   'Gpm6a',
#   'Syt13',
#   'Slc6a17',
#   'Pnpla3',
#   'Grid1',
#   'Nek10',
#   'Scn5a',
#   'Adam11',
#   'Miat',
#   'Lrfn5',
#   'Prdm6',
#   'D930020B18Rik',
#   'Chrdl1',
#   'Trpm5',
#   'Ly86',
#   'Atoh1',
#   'Smim3',
#   'Pou2f2',
#   'Arhgap22',
#   'Cd84',
#   'Hpse2',
#   'Spock1',
#   'Clnk',
#   'Elavl2',
#   'Col24a1',
#   'Cd244',
#   'Dnajc6',
#   'Lgi4',
#   'Dnah5',
#   'Ipcef1',
#   'Isl1',
#   'Igsf21',
#   'Phactr3',
#   'Ms4a6c',
#   'Gm12709',
#   'Faxc',
#   'Dscam',
#   'Nckap1l',
#   'Ptpn22',
#   'Etv5',
#   'Fam184a',
#   'Hck',
#   'Tnfsf15',
#   '9530059O14Rik',
#   'Rgs13',
#   'Galnt16',
#   'Bves',
#   'A630023A22Rik',
#   'Plet1',
#   'Col4a6',
#   'Ntng1',
#   'Plet1os',
#   'Gm15398',
#   'Wdfy4',
#   'Adgrg2',
#   'Astn1',
#   'Pappa',
#   'Tbx3os1',
#   'Gm2245',
#   'Ednra',
#   'Scube2',
#   'Fam19a5',
#   'Trpc4',
#   'Tph1',
#   'Cd48',
#   'RP24-274B19.1',
#   'Sh2d6',
#   'Rhbdl3',
#   '4833422C13Rik',
#   'Trpc3',
#   'Itga8',
#   'Rbm24',
#   'Fgf10',
#   'Tnr',
#   'Kcnj6',
#   'Dnah9',
#   'Piwil4',
#   'Insrr',
#   'Snhg11',
#   'A430078G23Rik',
#   'Kynu',
#   'Ramp1',
#   'Pacsin1',
#   'Scn7a',
#   'Itk',
#   'Myt1l',
#   'Stap1',
#   'Nkx2-2',
#   'Kcnq4',
#   'Gm14344',
#   'Myt1',
#   '4930578G10Rik',
#   'Nfasc',
#   'Cd22',
#   'Gm43388',
#   'Gm1123',
#   'Syt14',
#   'Prkcq',
#   'Gabrb3',
#   'Sytl5',
#   'Jph1',
#   'Slc8a3',
#   'Nalcn',
#   'Kcnn2',
#   'Runx3',
#   'Arhgap30',
#   'Apba2',
#   'Ntm',
#   'Stxbp5l',
#   'Rhoh',
#   'Ngf',
#   'Stat4',
#   'Rspo3',
#   'Xkr4',
#   'Tnfaip8',
#   'Tpd52l1',
#   'Dgki',
#   'Frem2',
#   'Gm14964',
#   'Gm43603',
#   'P2ry12',
#   'Slc38a11',
#   'Abcc8',
#   'Chat',
#   'Atp2c2',
#   'Gm20642',
#   'Btla',
#   'Galnt10',
#   'Abca8a',
#   'Agr2',
#   'Gria2',
#   'Skap1',
#   'Lmx1a',
#   'Ccdc129',
#   'Slc18a1',
#   'Spdef',
#   'Lrrtm3',
#   'Pik3cd',
#   'Nrg3os',
#   'Gm11149',
#   'March4',
#   'Dlgap2',
#   'C130071C03Rik',
#   'Ano7',
#   'Creb3l1',
#   'Gm38505',
#   'Slc12a8',
#   'Dscaml1',
#   'Adamts19',
#   'Vwa5b2',
#   'Kit',
#   'Rfx6',
#   'St18',
#   'Hepacam2',
#   'Tmem108',
#   'Pax5',
#   'Gfra1',
#   'Col11a1',
#   'Gm10848',
#   '9030622O22Rik',
#   'Ikzf3',
#   'Stk32a',
#   'Gm13269']}

# %%
#marker_gene_expression(adata, markers_dict, partition_key='pheno_cell_types')
